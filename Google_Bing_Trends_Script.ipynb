# %% [markdown]
# #### Link to Readme:
# https://github.com/Pawan429/DSCI_511_Project/blob/master/README.md

# %% [markdown]
# #### The following KEYWORDS DICTIONARY is extracted from Business Insider artice as mentioned in our Project Scope Document.
#
# https://www.businessinsider.com/things-to-do-in-quarantine-activities-social-distancing-2020-4?amp

# %%
Topics = {
"Streaming" : ["Quibi", "HBO", "Netflix", "Free Documentries", "Free Shows"],
"Exercises" : ["Yoga", "Walking", "Running", "Meditate", "Bicycle riding"],
"HBO_Shows" : ["Succession","True Blood","The Sopranos","Veep","The Wire"],
"Virtual_Games" : ["Animal Crossing: New Horizons", "Club Penguin", "Monopoly", "Mario Kart Tour","Words With Friends"],
"Cooking" : ["pancake", "pasta", "baking hacks", "bread", "cake", "cookie"],
"Video_Chat_Platforms" : ["Google hangouts", "Zoom", "QuarantineChat", "HouseParty","Zoom Party"],
"Live_Virtual_Performance" : ["Billie Eilish","BTS", "Dua Lipa", "Sophia Ankel"],
"Cameo" : ["Steven Galanis", "Rachel Dratch", "Mandy Moore", "Restaurant Workers' Relief Fund"],
"Social_Media" : ["Memes", "TikTok", "Instagram"],
"TikTok" : ["airplane","Hibachi grill","Hooters", "Ciara", "Usher", "Jennifer Lopez"],
"Instagram" : ["memes", "video chat", "makeup tutorials", "distance dance", "working_from_home"],
"Tiktok_Meme" : ["highschool musical", "dance workouts", "solo dance", "themed dinners", "distance dance"],
"Virtual_Workouts" : ["Gym", "Yoga", "Dancing", "Toning workout", "HIIT workout"],
}

# %% [markdown]
# #### ANACONDA DOESN'T COME PRE-INSTALLED WITH ALL OF THE FOLLOWING PACKAGES.
# Please kindly refer to requirements.txt to install all relevant packages.

# %%
#IMPORTING MODULES FOR GOOGLE TRENDS
import os
import pandas as pd
import pprint
from datetime import datetime, timedelta
from pytrends.request import TrendReq
import numpy as np

# %%
#INTIALINZING PYTRENDS
pytrends = TrendReq(hl='en-US', tz=360)

#date_range is a parameter used to ping the Google Trends API to get the data for 'last 5 months from today'.
date_range = (datetime.today() - timedelta(150)).strftime('%Y-%m-%d') + " " + datetime.today().strftime('%Y-%m-%d')

# %% [markdown]
# **GOOGLE TRENDS API** *takes a list of maximum 5 keywords as input and returns a dataframe for the feature interest_over_time.*
#
#
# *Some of the Topics in our Keyword Dictionary have more than 5 keywords. Hence, for the purpose of re-usability we've created a function to handle such Topics that have a length exceeding 5.*

# %%
#function to iterate over a list in batches of 5 & return a list of "lists with 5 elements"
def keyword_list_creator(keyword_list):
    new_list = []
    for i in range(int(len(keyword_list)/5)+1):
        new_list.append(keyword_list[i*5 : (i+1)*5])
    return(new_list)

# %%
#function to return interest_over_time dataframe & related queries from GOOGLE TRENDS 
#for a keyword list of **ONLY 5 elements**

def trend_df(channels):
    
    pytrends.build_payload(channels, cat=0,timeframe = date_range , geo='US', gprop='')

    interest_over_time = pytrends.interest_over_time().drop("isPartial",axis = 1)
    
    try:
        rel_queries = get_google_rel_queries(pytrends.related_queries())
    except:
        print("issue with google_rel_queries")
        rel_queries = []
    return(interest_over_time, rel_queries)


#function to return dataframe from GOOGLE TRENDS for a keyword list of **MORE THAN 5 KEYWORDS**

#uses the trend_df to create and stack  interest_over_time dataframes & Related queries lists 
#so as to return a single output

#Takes a keyword list as an input
#returns a transformed JSON of interest_over_time dataframe and a list of google related queries. 

def create_df(topic_name):
    
    keywords_list = keyword_list_creator(topic_name)
    
    if len(keywords_list[-1]) == 0:
        keywords_list = keywords_list[:-1]

    for i in range(len(keywords_list)):
        if i ==0:
            df, google_rel_queries = trend_df(keywords_list[i])
        else:
            df1, google_rel_queries_1 = trend_df(keywords_list[i])
            df = pd.concat([df, ], axis=1)
            google_rel_queries += google_rel_queries_1


    return(df.to_json(orient='table'),google_rel_queries)


#function to parse the google_related_queries JSON and return a list that contains only the related queries.
def get_google_rel_queries(google_rel_queries):
    rel_queries = []

    for i in google_rel_queries.keys():
#         print(i)
        try :
            rel_queries += list(google_rel_queries[i]['top']["query"][:])
        except:
            continue        

    rel_queries = list(set(rel_queries))
    return(rel_queries)

# %% [markdown]
# **GOOGLE TRENDS** *returns a JSON response for related queries. The JSON response is comprised of two parts i.e... 'rising' and 'top'. For the purposes of this project we have limited our scope to only extract the 'top' related queries.*

# %%
#IMPORTING RELEVANT MODULES TO INTERACT WITH AZURE COGNITIVE SERVICES(BING SEARCH TRENDS)

import requests
from azure.cognitiveservices.search.websearch import WebSearchClient
from azure.cognitiveservices.search.websearch.models import SafeSearch
from msrest.authentication import CognitiveServicesCredentials
from jsonpath_ng import jsonpath, parse

# %%
#FREE SUBSCRIPTION KEY FOR AZURE
subscription_key = "ad77b0574afa46dcac9fefd0324e69b6"
assert subscription_key

# %%
#function to connect to bing API and return a list of related queries.

def get_bing_results(keyword_list):

    bing_rel_queries_complete_list = []
    for i in keyword_list:
        headers = {"Ocp-Apim-Subscription-Key": subscription_key}
        params = {"q": i, "textDecorations": True, "textFormat": "HTML"}
        response = requests.get("https://api.cognitive.microsoft.com/bing/v7.0/search", headers=headers, params=params)
        response.raise_for_status()    
        bing_rel_queries_complete_list += rel_query_preprocessing(response.json())
        
    return(bing_rel_queries_complete_list)


#function to parse the bing_related_queries JSON and return a list that contains only the related queries.
#Used JSONPATH to parse the json

def rel_query_preprocessing(bing_search_result_json):
    
    try:
        raw_data = bing_search_result_json['relatedSearches']
        jsonpath_expr = parse('$..text')
        bing_rel_queries = [match.value for match in jsonpath_expr.find(raw_data)]
    
    except KeyError:
        bing_rel_queries = []
        
    bing_rel_queries = list(set(bing_rel_queries))
    
    return(bing_rel_queries)

# %% [markdown]
# ### The Output JSON will be created in the following format.
#
#
#     {"Topic Name" :
#          {"interest over time" : #Dataframe
#
#         "related_queries" :
#                     {
#                       "Google": #list
#                       "Bing" :  #list
#                       }
#          }
#     }

# %%
#FUNCTION TO CREATE THE FINAL JSON OBJECT IN THE STRUCTURE SHOWN ABOVE.

#Takes the KEYWORDS DICTIONARY as Input.
#Returns a Json Object and a List of "Left over Topics"('Topics that didn't work) as output.
#iterates through the KEYWORDS DICTIONARY.
#makes use of all the above defined functions to create the output JSON object.

def create_final_json(Topics):
    final_json = {}
    worked_topics = []
    for i in Topics.keys():
        
        try:
            final_json[i] = {}
            final_json[i]["related_queries"] = {}
            final_json[i]["interest_over_time"],final_json[i]["related_queries"]["Google"] = create_df(Topics[i])
            try:
                final_json[i]["related_queries"]["Bing"] = get_bing_results(Topics[i])
            except:
                print("issue with BING!")
                final_json[i]["related_queries"]["Bing"] = []
                
            worked_topics.append(i)
            print(i,"is processed.")
        except:
            continue
            
    left_out_topics = [x for x in Topics.keys() if x not in worked_topics]
    return(final_json, left_out_topics)

# create_final_json(Topics)

# %%
# CREATE THE FINAL JSON
final_json, left_out_topics = create_final_json(Topics)
# Out:
# Streaming is processed.
# Exercises is processed.
# HBO_Shows is processed.
# Virtual_Games is processed.
# Cooking is processed.
# Video_Chat_Platforms is processed.
# Live_Virtual_Performance is processed.
# Cameo is processed.
# Social_Media is processed.
# TikTok is processed.
# Instagram is processed.
# Tiktok_Meme is processed.
# Virtual_Workouts is processed.

# %%
# CHECK IF THERE ARE ANY LEFT-OVER TOPICS/KEYWORD LISTS
left_out_topics
# Out:
# []

# %%
# CHECK OUT THE FINAL JSON OBJECT
final_json
# Out:
# {'Streaming': {'related_queries': {'Google': ['quibi movie',
#     'free netflix',
#     'hbo login',
#     'good movies on netflix',
#     'the stranger',
#     'quibi reno 911',
#     'quibi t mobile',
#     'quibi price',
#     'netflix outer banks',
#     'hulu',
#     'new hbo',
#     'hbo shows',
#     'you netflix',
#     'free tv shows online',
#     'the outsider',
#     'netflix shows',
#     'hulu hbo',
#     'quibi dummy',
#     'netflix new movies',
#     'tv shows for free',
#     'broadway shows',
#     'what is quibi',
#     'best netflix movies',
#     'good netflix movies',
#     'netflix stock',
#     'netflix movies 2020',
#     'quibi review',
#     'hulu shows',
#     'hollywood netflix',
#     'netflix login',
#     'netflix account',
#     'watch shows free',
#     'hbo amazon prime',
#     'tv shows free',
#     'free shows online',
#     'netflix movies',
#     'quibi ipo',
#     'hbo max',
#     'quibi app',
#     'movies on hbo',
#     'new on netflix',
#     'watch shows for free',
#     'shows on netflix',
#     'dummy',
#     'free movies',
#     'free movies online',
#     'watch shows online free',
#     'hbo now',
#     'tv shows',
#     'survive quibi',
#     'hbo movies',
#     'reno 911',
#     'quibi streaming',
#     'hbo schedule',
#     'best movies on netflix',
#     'outer banks',
#     'the outsider hbo',
#     'watch free movies',
#     'quibi stock',
#     'quibi free',
#     'quibi commercial',
#     'hbo go',
#     'tv shows online',
#     '123movies',
#     'watch free tv shows',
#     'quibi tv',
#     'free shows and movies',
#     'hbo free shows',
#     'most dangerous game',
#     'amazon hbo',
#     'quibi the stranger',
#     'hbo show',
#     'hbo free',
#     'movies on netflix',
#     'you on netflix',
#     'hbo streaming',
#     'watch free tv shows online',
#     'quibi stock price',
#     'outsider hbo',
#     'free broadway shows',
#     'showtime',
#     'quibi shows',
#     'stream tv shows free',
#     'hbo',
#     'hbo on hulu',
#     'watch hbo',
#     'netflix series',
#     'best hbo movies',
#     'quibi movies',
#     'best shows on netflix',
#     'quibi most dangerous game',
#     'hbo run',
#     'hbo series',
#     'best netflix shows',
#     'quibi cost',
#     'free movies and tv shows',
#     'netflix party'],
#    'Bing': ['ubi internet banking',
#     'qui ubi banca imprese',
#     'qui ubi login',
#     'ubi banca qui ubi',
#     'qui ubi france',
#     'qui ubi banca online',
#     'ubi banca home banking',
#     'ubi banca internet banking',
#     'hbo tv schedule tonight',
#     'hbo now tv code',
#     'free hbo',
#     'is hbo free this week',
#     'watch free hbo online channel',
#     'hbo go app free',
#     'hbo today schedule',
#     'hbo new movies tonight',
#     'history channel documentaries free online',
#     'pbs documentaries online free',
#     'pbs history documentaries free online',
#     'youtube free documentaries full length',
#     'free american history documentaries',
#     'watch free full length documentaries',
#     'discovery channel documentaries free online',
#     'free documentaries youtube history channel',
#     'watch free live stream movies',
#     'watch tv programs free online',
#     'old tv shows free youtube',
#     'free shows online full episodes',
#     'watch full tv episodes for free online',
#     'free online tv show websites',
#     'tv shows online for free',
#     'free tv episodes online no registration']},
#   'interest_over_time': '{"schema":{"fields":[{"name":"date","type":"datetime"},{"name":"Quibi","type":"integer"},{"name":"HBO","type":"integer"},{"name":"Netflix","type":"integer"},{"name":"Free Documentries","type":"integer"},{"name":"Free Shows","type":"integer"}],"primaryKey":["date"],"pandas_version":"0.20.0"},"data":[{"date":"2020-01-07T00:00:00.000Z","Quibi":0,"HBO":4,"Netflix":50,"Free Documentries":0,"Free Shows":0},{"date":"2020-01-08T00:00:00.000Z","Quibi":0,"HBO":4,"Netflix":46,"Free Documentries":0,"Free Shows":0},{"date":"2020-01-09T00:00:00.000Z","Quibi":0,"HBO":4,"Netflix":47,"Free Documentries":0,"Free Shows":0},{"date":"2020-01-10T00:00:00.000Z","Quibi":0,"HBO":4,"Netflix":47,"Free Documentries":0,"Free Shows":0},{"date":"2020-01-11T00:00:00.000Z","Quibi":0,"HBO":6,"Netflix":60,"Free Documentries":0,"Free Shows":0},{"date":"2020-01-12T00:00:00.000Z","Quibi":0,"HBO":7,"Netflix":59,"Free Documentries":0,"Free Shows":0},{"date":"2020-01-13T00:00:00.000Z","Quibi":0,"HBO":9,"Netflix":45,"Free Documentries":0,"Free Shows":0},{"date":"2020-01-14T00:00:00.000Z","Quibi":0,"HBO":7,"Netflix":41,"Free Documentries":0,"Free Shows":0},{"date":"2020-01-15T00:00:00.000Z","Quibi":0,"HBO":6,"Netflix":45,"Free Documentries":0,"Free Shows":0},{"date":"2020-01-16T00:00:00.000Z","Quibi":0,"HBO":6,"Netflix":45,"Free Documentries":0,"Free Shows":0},{"date":"2020-01-17T00:00:00.000Z","Quibi":0,"HBO":6,"Netflix":50,"Free Documentries":0,"Free Shows":0},{"date":"2020-01-18T00:00:00.000Z","Quibi":0,"HBO":9,"Netflix":67,"Free Documentries":0,"Free Shows":0},{"date":"2020-01-19T00:00:00.000Z","Quibi":0,"HBO":10,"Netflix":63,"Free Documentries":0,"Free Shows":0},{"date":"2020-01-20T00:00:00.000Z","Quibi":0,"HBO":11,"Netflix":59,"Free Documentries":0,"Free Shows":0},{"date":"2020-01-21T00:00:00.000Z","Quibi":0,"HBO":7,"Netflix":51,"Free Documentries":0,"Free Shows":0},{"date":"2020-01-22T00:00:00.000Z","Quibi":0,"HBO":5,"Netflix":45,"Free Documentries":0,"Free Shows":0},{"date":"2020-01-23T00:00:00.000Z","Quibi":0,"HBO":4,"Netflix":45,"Free Documentries":0,"Free Shows":0},{"date":"2020-01-24T00:00:00.000Z","Quibi":0,"HBO":4,"Netflix":45,"Free Documentries":0,"Free Shows":0},{"date":"2020-01-25T00:00:00.000Z","Quibi":0,"HBO":7,"Netflix":60,"Free Documentries":0,"Free Shows":0},{"date":"2020-01-26T00:00:00.000Z","Quibi":0,"HBO":6,"Netflix":57,"Free Documentries":0,"Free Shows":0},{"date":"2020-01-27T00:00:00.000Z","Quibi":0,"HBO":6,"Netflix":41,"Free Documentries":0,"Free Shows":0},{"date":"2020-01-28T00:00:00.000Z","Quibi":0,"HBO":4,"Netflix":39,"Free Documentries":0,"Free Shows":0},{"date":"2020-01-29T00:00:00.000Z","Quibi":0,"HBO":4,"Netflix":38,"Free Documentries":0,"Free Shows":0},{"date":"2020-01-30T00:00:00.000Z","Quibi":0,"HBO":4,"Netflix":39,"Free Documentries":0,"Free Shows":0},{"date":"2020-01-31T00:00:00.000Z","Quibi":0,"HBO":4,"Netflix":44,"Free Documentries":0,"Free Shows":0},{"date":"2020-02-01T00:00:00.000Z","Quibi":0,"HBO":6,"Netflix":57,"Free Documentries":0,"Free Shows":0},{"date":"2020-02-02T00:00:00.000Z","Quibi":1,"HBO":6,"Netflix":57,"Free Documentries":0,"Free Shows":0},{"date":"2020-02-03T00:00:00.000Z","Quibi":1,"HBO":4,"Netflix":36,"Free Documentries":0,"Free Shows":0},{"date":"2020-02-04T00:00:00.000Z","Quibi":0,"HBO":5,"Netflix":39,"Free Documentries":0,"Free Shows":0},{"date":"2020-02-05T00:00:00.000Z","Quibi":0,"HBO":4,"Netflix":38,"Free Documentries":0,"Free Shows":0},{"date":"2020-02-06T00:00:00.000Z","Quibi":0,"HBO":4,"Netflix":40,"Free Documentries":0,"Free Shows":0},{"date":"2020-02-07T00:00:00.000Z","Quibi":0,"HBO":4,"Netflix":45,"Free Documentries":0,"Free Shows":0},{"date":"2020-02-08T00:00:00.000Z","Quibi":0,"HBO":6,"Netflix":56,"Free Documentries":0,"Free Shows":0},{"date":"2020-02-09T00:00:00.000Z","Quibi":0,"HBO":6,"Netflix":61,"Free Documentries":0,"Free Shows":0},{"date":"2020-02-10T00:00:00.000Z","Quibi":1,"HBO":5,"Netflix":45,"Free Documentries":0,"Free Shows":0},{"date":"2020-02-11T00:00:00.000Z ...
#  'Exercises': {'related_queries': {'Google': ['walking dead',
#     'meditate on the word',
#     'brooks shoes',
#     'running for president',
#     'hot yoga',
#     'nike running shoes',
#     'fear the walking dead',
#     'corepower yoga',
#     'walking away',
#     'how do i meditate',
#     'yoga near me',
#     'running shorts',
#     'meditate synonym',
#     'running boards',
#     'walking out',
#     'running store',
#     'lenovo yoga',
#     'dog walking',
#     'how to meditate properly',
#     'learn how to meditate',
#     'online yoga',
#     'running away',
#     'brooks running',
#     'yoga mat',
#     'on running shoes',
#     'how to meditate reddit',
#     'the walking dead cast',
#     'women running shoes',
#     'meditate meaning',
#     'benefits of meditation',
#     'best way to meditate',
#     'can you meditate lying down',
#     'the walking dead',
#     'yoga pose',
#     'best time to meditate',
#     'biden running mate',
#     'cosmic yoga',
#     'walking tall',
#     'yoga pants',
#     'meditate day and night',
#     'power yoga',
#     'womens running shoes',
#     'people running',
#     'why meditate',
#     'bicycle riding shorts',
#     'yoga poses',
#     'walking shoes',
#     'asics',
#     'yoga workout',
#     'cosmic kids yoga',
#     'alo yoga',
#     'best shoes for walking',
#     'ways to meditate',
#     'yoga classes',
#     'kids yoga',
#     'free yoga',
#     'best running shoes',
#     'meditate before or after workout',
#     'how long to meditate',
#     'walking trails',
#     'meditate lyrics',
#     'how to meditate',
#     'learn to meditate',
#     'calories burned walking',
#     'yoga with adriene',
#     'adriene yoga',
#     'walking dead season 10',
#     'pneumonia',
#     'define meditate',
#     'yoga class',
#     'running shoes',
#     'how long should you meditate',
#     'walking stick',
#     'brooks running shoes',
#     'walking pneumonia',
#     'people walking',
#     'nike running',
#     'bikram yoga',
#     'walking exercise',
#     'beginners yoga',
#     'calories walking',
#     'on shoes',
#     'how to meditate for beginners',
#     'nike shoes',
#     'asics running',
#     'yoga studio',
#     'walking dead cast',
#     'running back',
#     'meditate definition',
#     'meditation',
#     'walking trails near me',
#     'best shoes for running',
#     'rick walking dead',
#     'what is yoga',
#     'yoga youtube',
#     'how do you meditate',
#     'running man',
#     'on running',
#     'the walking dead season 10',
#     'best walking shoes',
#     'walking company'],
#    'Bing': ['morning yoga with adriene youtube',
#     'how to start yoga',
#     'yoga for beginners',
#     'yoga near me',
#     'yoga with adrienne youtube channel',
#     'yoga poses',
#     'youtube yoga videos',
#     'why yoga is beneficial',
#     '10 benefits of walking everyday',
#     'benefits of walking pdf',
#     'benefits of walking 1 hour a day',
#     'walking 2 miles a day',
#     'health benefits of walking daily',
#     'walking store company',
#     'what does walking do',
#     'walking health benefits',
#     'runnings farm and fleet locations',
#     'printable half marathon training schedule',
#     'runnings putnam ct',
#     'brooks running',
#     'running farm and fleet',
#     'running store near me',
#     'runnings farm and fleet online',
#     'running shoes women',
#     'meditation for beginners',
#     'what is meditation definition',
#     'how do you meditate',
#     'learning to meditate',
#     'how do i meditate',
#     'ways to meditate',
#     'meditate on god&#39;s word',
#     'how to meditate for anxiety',
#     'bicycle riding groups near me',
#     'bicycle riding for exercise',
#     'benefits of riding a bike',
#     'bicycle riding gear',
#     'is bike riding good exercise',
#     'bicycle riding for seniors',
#     'bicycle riding pants',
#     'women riding bicycles images']},
#   'interest_over_time': '{"schema":{"fields":[{"name":"date","type":"datetime"},{"name":
#     'the sopranos season 1',
#     'the wire',
#     'primary succession and secondary succession',
#     'order of succession',
#     'seasons of true blood',
#     'true blood lafayette',
#     'veep season 7',
#     'secondary succession',
#     'line of succession',
#     'omar',
#     'ecological succession',
#     'pioneer species',
#     'eric true blood',
#     'imdb veep',
#     'the sopranos season 2',
#     'dan egan veep',
#     'watch the wire',
#     'what is veep',
#     'jonah veep',
#     'season 3 succession',
#     'james gandolfini',
#     'veep season 4',
#     'tony soprano',
#     'bill true blood',
#     'watch true blood',
#     'breitbart',
#     'what is primary succession',
#     'deborah ann woll',
#     'true blood imdb',
#     'anna paquin',
#     'the wire news',
#     'the daily caller',
#     'tara true blood',
#     'in succession',
#     'the wire series',
#     'succession definition',
#     'veep seasons',
#     'paulie the sopranos',
#     'over the wire',
#     'sopranos season 1',
#     'daily wire',
#     'cast succession',
#     'sopranos season 3',
#     'how many seasons of the sopranos',
#     'hbo succession',
#     'the wire lyrics',
#     'veep definition',
#     'true blood cast',
#     'the veep',
#     'season 2 succession',
#     'presidential succession',
#     'veep season 8',
#     'succession of president',
#     'watch veep',
#     'the sopranos cast',
#     'true blood episodes',
#     'the wire season 1',
#     'veep season 2',
#     'veep wiki',
#     'the blaze',
#     'the wire michael',
#     'the sopranos season 5',
#     'the succession',
#     'veep meaning',
#     'the daily wire',
#     'what is succession',
#     'the wire omar',
#     'true blood books',
#     'true blood song',
#     'the wire walmart',
#     'under the wire',
#     'season 2 the wire',
#     'definition of succession',
#     'cast of true blood',
#     'wire transfer',
#     'true blood season 1',
#     'jason true blood',
#     'watch the sopranos',
#     'veep season 6',
#     'true blood season 2',
#     'primary succession',
#     'true blood season 7',
#     'hbo',
#     'sopranos season 6',
#     'cast of the sopranos',
#     'season 4 true blood',
#     'amy veep',
#     'daily caller',
#     'season 4 the wire',
#     'succession of the president',
#     'jessica true blood',
#     'minna veep',
#     'true blood sookie',
#     'gary veep',
#     'the wire cast',
#     'the sopranos episodes',
#     'walmart wire',
#     'the high wire',
#     'christopher the sopranos',
#     'cast of veep',
#     'primary and secondary succession',
#     'what is secondary succession',
#     'season 3 true blood',
#     'veep season 3',
#     'true blood netflix',
#     'sopranos movie',
#     'the sopranos season 3',
#     'president succession',
#     'true blood seasons'],
#    'Bing': ['how to file a succession in louisiana',
#     'succession season 2',
#     'succession cast season 2',
#     'succession plot summary',
#     'succession tv show episodes',
#     'succession hbo season 3',
#     'hbo succession cast',
#     'succession tv series',
#     'true blood books',
#     'true blood season 4 cast',
#     'true blood series 1 7',
#     'true blood season 6',
#     'true blood season 8 release',
#     'true blood watch free online',
#     'true blood tv show cast',
#     'true blood show',
#     'the cast of the sopranos',
#     'sopranos full episodes free online',
#     'the sopranos full episodes free',
#     'watch the sopranos online free',
#     'full cast of the sopranos',
#     'sopranos season 2 cast list',
#     'the sopranos season 2',
#     'the sopranos ending',
#     'veep episode guide wiki',
#     'veep series finale recap',
#     'veep definition',
#     'veep season 8',
#     'veep episode guide',
#     'veep season 6 cast',
#     'veep ending',
#     'veep cast',
#     'wynn the wire',
#     'the wire episode 1',
#     'cast of the wire characters',
#     'the wire characters',
#     'the wire tv show episodes',
#     'the wire movie cast',
#     'hbo series the wire episodes',
#     'the wire full episodes free']},
#   'interest_over_time': '{"schema":{"fields":[{"name":"date","type":"datetime"},{"name":
ep":4,"The Wire":44},{"date":"2020-01-29T00:00:00.000Z","Succession":35,"True Blood":12,"The Sopranos":8,"Veep":4,"The Wire":44},{"date":"2020-01-30T00:00:00.000Z","Succession":41,"True Blood":13,"The Sopranos":10,"Veep":3,"The Wire":46},{"date":"2020-01-31T00:00:00.000Z","Succession":32,"True Blood":12,"The Sopranos":10,"Veep":3,"The Wire":45},{"date":"2020-02-01T00:00:00.000Z","Succession":26,"True Blood":12,"The Sopranos":10,"Veep":5,"The Wire":44},{"date":"2020-02-02T00:00:00.000Z","Succession":27,"True Blood":16,"The Sopranos":8,"Veep":5,"The Wire":50},{"date":"2020-02-03T00:00:00.000Z","Succession":26,"True Blood":14,"The Sopranos":5,"Veep":2,"The Wire":40},{"date":"2020-02-04T00:00:00.000Z","Succession":31,"True Blood":14,"The Sopranos":9,"Veep":7,"The Wire":47},{"date":"2020-02-05T00:00:00.000Z","Succession":41,"True Blood":16,"The Sopranos":7,"Veep":8,"The Wire":52},{"date":"2020-02-06T00:00:00.000Z","Succession":34,"True Blood":13,"The Sopranos":6,"Veep":3,"The Wire":48},{"date":"2020-02-07T00:00:00.000Z","Succession":29,"True Blood":13,"The Sopranos":9,"Veep":5,"The Wire":47},{"date":"2020-02-08T00:00:00.000Z","Succession":28,"True Blood":13,"The Sopranos":11,"Veep":5,"The Wire":45},{"date":"2020-02-09T00:00:00.000Z","Succession":30,"True Blood":19,"The Sopranos":10,"Veep":4," ...
#  'Virtual_Games': {'related_queries': {'Google': ['animal crossing new horizons designs',
#     'clubpenguin',
#     'words with friends help',
#     'qr codes animal crossing new horizons',
#     'animal jam',
#     'games',
#     'mario kart tour cheats',
#     'animal crossing qr codes',
#     'mario kart tour friend id',
#     'monopoly game board',
#     'mario kart tour twitter',
#     'how to play monopoly',
#     'monopoly pieces',
#     'club penguin rewritten codes',
#     'mario kart tour tier list',
#     'cheats words with friends',
#     'words with friends screenshot cheat',
#     'animal crossing new horizons new villagers',
#     'animal crossing new horizons villagers',
#     'online games',
#     'play monopoly online',
#     'words with friends generator',
#     'animal crossing new horizons price',
#     'cheat words with friends',
#     'club penguin online',
#     'puffles club penguin',
#     'animal crossing new horizons guide',
#     'words with friends cheat with board',
#     'word generator words with friends',
#     'words cheat',
#     'animal crossing new horizons fruit',
#     'monopoly deal',
#     'how much monopoly money',
#     'monopoly online',
#     'monopoly rules',
#     'words with friends board',
#     'monopoly man',
#     'animal crossing amiibo',
#     'reddit animal crossing new horizons',
#     'monopoly definition',
#     'monopoly free',
#     'mature club penguin servers',
#     'club penguin back',
#     'kadomatsu mario kart tour',
#     'mario kart tour friends',
#     'monopoly houses',
#     'mario kart tour sidestepper',
#     'animal crossing new horizons fish',
#     'what is club penguin',
#     'friends monopoly',
#     'club penguin mission',
#     'animal crossing new horizons reddit',
#     'what is monopoly',
#     'monopoly game',
#     'mario kart tour wiki',
#     'mario kart tour all characters',
#     'mario kart tour standard races',
#     'poptropica',
#     'club penguin new',
#     'dictionary words with friends',
#     'words with friends scrabble',
#     'animal crossing reddit',
#     'nintendo switch',
#     'disney club penguin',
#     'club penguin codes',
#     'club penguin rewritten',
#     'monopoly board',
#     'monopoly plus',
#     'animal crossing switch',
#     'club penguin login',
#     'mario kart tour friend codes',
#     'mario kart tour shortcuts',
#     'natural monopoly',
#     'mario kart tour news',
#     'word finder words with friends',
#     'words for words with friends',
#     'help with words with friends',
#     'multiplayer mario kart tour',
#     'words with friends app',
#     'monopoly mcdonalds',
#     'words with friends screenshot',
#     'webkinz',
#     'words with friends game',
#     'kadomatsu',
#     'how to play with friends on mario kart tour',
#     'what is a monopoly',
#     'club penguin games',
#     'word with friends',
#     'thwomp mario kart tour',
#     'animal crossing villagers',
#     'club penguin names',
#     'mario kart tour apk',
#     'bugs animal crossing new horizons',
#     'flowers animal crossing new horizons',
#     'monopoly money start',
#     'club penguin island',
#     'how much money in monopoly',
#     'reddit mario kart tour',
#     'words with friends cheat words',
#     'monopoly money',
#     'cheat with words with friends',
#     'puffle club penguin',
#     'animal crossing designs',
#     'amiibo',
#     'what is animal crossing new horizons',
#     'safeway monopoly',
#     'word finder',
#     'sidesteppers mario kart tour',
#     'animal crossing new leaf',
#     'animal crossing new horizons switch',
#     'words with friends 2 cheat',
#     'nintendo',
#     'words with friends finder',
#     'club penguin code',
#     'words with friends helper',
#     'amiibo animal crossing new horizons',
#     'club penguin online codes',
#     'club penguin codes 2020',
#     'cheat in words with friends',
#     'monopoly games'],
#    'Bing': ['animal crossing new horizons tips and tricks',
#     'animal crossing nintendo switch edition',
#     'animal crossing new horizon characters',
#     'animal crossing new horizons strategy guide',
#     'animal crossing new horizons villagers',
#     'nintendo switch animal crossing bundle',
#     'animal crossing new horizons switch bundle',
#     'animal crossing new horizons website',
#     'play club penguin',
#     'club penguin online old',
#     'club penguin old version',
#     'club penguin coin generator',
#     'club penguin online sign in',
#     'club penguin app',
#     'is club penguin online safe',
#     'club penguin wiki',
#     'monopoly online',
#     'hasbro monopoly for windows 10',
#     'monopoly board game',
#     'play monopoly online against computer',
#     'hasbro monopoly online free',
#     'monopoly free play full version',
#     'monopoly online no download required',
#     'monopoly free full version games',
#     'mario kart google play',
#     'mario kart tour for pc',
#     'mario kart tour unblocked 66',
#     'play mario kart online free',
#     'mario kart tour apk',
#     'mario kart tour cheats',
#     'mario kart tour friend codes',
#     'mario kart tour characters list',
#     'words with friends classic',
#     'words with friends windows download',
#     'words with friends log in',
#     'words with friends original game',
#     'download newest version of words with friends',
#     'words with friends help',
#     'words with friends solo cheat',
#     'words with friends 2 cheats']},
#   'interest_over_time': '{"schema":{"fields":[{"name":"date","type":"datetime"},{"name":"Animal Crossing: New Horizons","type":"integer"},{"name":"Club Penguin","type":"integer"},{"name":"Monopoly","type":"integer"},{"name":"Mario Kart Tour","type":"integer"},{"name":"Words With Friends","type":"integer"}],"primaryKey":["date"],"pandas_version":"0.20.0"},"data":[{"date":"2020-01-07T00:00:00.000Z","Animal Crossing: New Horizons":0,"Club Penguin":2,"Monopoly":5,"Mario Kart Tour":1,"Words With Friends":7},{"date":"2020-01-08T00:00:00.000Z","Animal Crossing: New Horizons":1,"Club Penguin":1,"Monopoly":4,"Mario Kart Tour":1,"Words With Friends":8},{"date":"2020-01-09T00:00:00.000Z","Animal Crossing: New Horizons":0,"Club Penguin":2,"Monopoly":5,"Mario Kart Tour":1,"Words With Friends":7},{"date":"2020-01-10T00:00:00.000Z","Animal Crossing: New Horizons":1,"Club Penguin":2,"Monopoly":5,"Mario Kart Tour":1,"Words With Friends":7},{"date":"2020-01-11T00:00:00.000Z","Animal Crossing: New Horizons":1,"Club Penguin":1,"Monopoly":6,"Mario Kart Tour":1,"Words With Friends":8},{"date":"2020-01-12T00:00:00.000Z","Animal Crossing: New Horizons":1,"Club Penguin":2,"Monopoly":7,"Mario Kart Tour":1,"Words With Friends":8},{"date":"2020-01-13T00:00:00.000Z","Animal Crossing: New Horizons":1,"Club Penguin":2,"Monopoly":5,"Mario Kart Tour":1,"Words With Friends":7},{"date":"2020-01-14T00:00:00.000Z","Animal Crossing: New Horizons":1,"Club Penguin":1,"Monopoly":5,"Mario Kart Tour":1,"Words With Friends":6},{"date":"2020-01-15T00:00:00.000Z","Animal Crossing: New Horizons":1,"Club Penguin":1,"Monopoly":5,"Mario Kart Tour":1,"Words With Friends":7},{"date":"2020-01-16T00:00:00.000Z","Animal Crossing: New Horizons":1,"Club Penguin":2,"Monopoly":5,"Mario Kart Tour":0,"Words With Friends":6},{"date":"2020-01-17T00:00:00.000Z","Animal Crossing: New Horizons":0,"Club Penguin":2,"Monopoly":5,"Mario Kart Tour":0,"Words With Friends":7},{"date":"2020-01-18T00:00:00.000Z","Animal Crossing: New Horizons":1,"Club Penguin":2,"Monopoly":5,"Mario Kart Tour":1,"Words With Friends":7},{"date":"2020-01-19T00:00:00.000Z","Animal Crossing: New Horizons":1,"Club Penguin":2,"Monopoly":6,"Mario Kart Tour":0,"Words With Friends":8},{"date":"2020-01-20T00:00:00.000Z","Animal Crossing: New Horizons":1,"Club Penguin":2,"Monopoly":5,"Mario Kart Tour":0,"Words With Friends":7},{"date":"2020-01-21T00:00:00.000Z","Animal Crossing: New Horizons":1,"Club Penguin":2,"Monopoly":4,"Mario Kart Tour":0,"Words With Friends":7},{"date":"2020-01-22T00:00:00.000Z","Animal Crossing: New Horizons":1,"Club Penguin":2,"Monopoly":5,"Mario Kart Tour":0,"Words With Friends":7},{"date":"2020-01-23T00:00:00.000Z","Animal Crossing: New Horizons":1,"Club Penguin":2,"Monopoly":4,"Mario Kart Tour":0,"Words With Friends":8},{"date":"2020-01-24T00:00:00.000Z","Animal Crossing: New Horizons":1,"Club Penguin":2,"Monopoly":4,"Mario Kart Tour":0,"Words With Friends":7},{"date":"2020-01-25T00:00:00.000Z","Animal Crossing: New Horizons":1,"Club Penguin":2,"Monopoly":6,"Mario Kart Tour":0,"Words With Friends":8},{"date":"2020-01-26T00:00:00.000Z","Animal Crossing: New Horizons":1,"Club Penguin":2,"Monopoly":6,"Mario Kart Tour":0,"Words With Friends":8},{"date":"2020-01-27T00:00:00.000Z","Animal Crossing: New Horizons":1,"Club Penguin":2,"Monopoly":4,"Mario Kart Tour":0,"Words With Friends":6},{"date":"2020-01-28T00:00:00.000Z","Animal Crossing: New Horizons":1,"Club Penguin":2,"Monopoly":5,"Mario Kart Tour":1,"Words With Friends":8},{"date":"2020-01-29T00:00:00.000Z","Animal Crossing: New Horizons":1,"Club Penguin":2,"Monopoly":4,"Mario Kart Tour":0,"Words With Friends":7},{"date":"2020-01-30T00:00:00.000Z","Animal Crossing: New Horizons":1,"Club Penguin":2,"Monopoly":4,"Mario Kart Tour":0,"Words With Friends":8},{"date":"2020-01-31T00:00:00.000Z","Animal Crossing: New Horizons":2,"Club Penguin":2,"Monopoly":4,"Mario Kart Tour":0,"Words With Friends":6},{"date":"2020-02-01T00:00:00.000Z","Animal Crossing: New Hor ...
#  'Cooking': {'related_queries': {'Google': ['chocolate cake',
#     'cake near me',
#     'how to make pancake',
#     'pineapple cake',
#     'how to make bread',
#     'pancake near me',
#     'cake frosting',
#     'how to make pancake mix',
#     'pancake syrup',
#     'ice cream cake',
#     'how to make cake',
#     'cake flour',
#     'cajun pasta',
#     'the pancake house',
#     'lemon pasta',
#     'banana bread',
#     'homemade pancake',
#     'original pancake house',
#     'strawberry cake',
#     'panera menu',
#     'aunt jemima pancake',
#     'spaghetti',
#     'pancake recipes',
#     'chicken pasta recipes',
#     'pasta salad',
#     'white bread',
#     'how to make pasta',
#     'cheese cake',
#     'mug cake',
#     'bread crumbs',
#     'cake recipe',
#     'french bread',
#     'pancake mix recipe',
#     'bundt cake',
#     'panera bread',
#     'panera',
#     'penne pasta',
#     'pound cake',
#     'pasta near me',
#     'bread recipes',
#     'chicken recipes',
#     'bread yeast',
#     'bread machine',
#     'bread pudding',
#     'pasta noodles',
#     'cake pan',
#     'sausage pasta',
#     'bread flour',
#     'pancake house',
#     'homemade bread',
#     'cake mix',
#     'our daily bread',
#     'pancake cake',
#     'homemade pasta',
#     'wheat bread',
#     'pancake mix',
#     'breakfast',
#     'sourdough bread',
#     'japanese pancake',
#     'easy bread recipe',
#     'pasta sauce recipe',
#     'wedding cake',
#     'chicken pasta',
#     'easy pancake recipe',
#     'pesto pasta',
#     'pancakes recipe',
#     'chocolate cake recipe',
#     'lemon cake',
#     'banana banana bread',
#     'daily bread',
#     'bread recipe',
#     'pancake batter',
#     'pancake day',
#     'alfredo pasta',
#     'garlic pasta',
#     'cake recipes',
#     'keto bread',
#     'shrimp pasta',
#     'fresh pasta',
#     'chocolate',
#     'chicken and pasta',
#     'spinach pasta',
#     'pasta recipe',
#     'carrot cake',
#     'butter cake',
#     'coffee cake',
#     'pasta recipes',
#     'garlic bread',
#     'pasta sauce',
#     'pancake recipe',
#     'gluten free bread',
#     'panera bread menu',
#     'birthday cake',
#     'vanilla cake',
#     'pancakes',
#     'pizza pasta',
#     'banana pancake',
#     'ihop',
#     'aunt jemima',
#     'pancake breakfast',
#     'cookie clicker',
#     'butter cookie recipe',
#     'chocolate cookie',
#     'cookie dough',
#     'chocolate chip cookie',
#     'chocolate cookie recipe',
#     'girl scout cookie',
#     'chocolate chip cookie recipe',
#     'cookie monster',
#     'fortune cookie',
#     'edible cookie dough',
#     'cookies',
#     'american cookie',
#     'sugar cookie',
#     'cookie butter',
#     'chocolate chip cookies',
#     'cookie recipe',
#     'cookie recipes',
#     'cookie cutter',
#     'oatmeal cookie recipe',
#     'sugar cookie recipe',
#     'cookies recipe',
#     'peanut butter cookie',
#     'cookie jar',
#     'cookie cake'],
#    'Bing': ['easy homemade pancakes',
#     'simple pancake recipe from scratch',
#     'best fluffy pancake recipe',
#     'fluffy pancake recipe',
#     'old fashioned pancakes from scratch',
#     'simple pancake recipe for one',
#     'easy fluffy pancakes recipe from scratch',
#     'the best homemade pancake recipe from scratch',
#     'types of pasta list',
#     'pasta noodles types',
#     'pasta ingredients',
#     'pasta salad with italian dressing',
#     'mail order pasta',
#     'pasta shapes and names chart',
#     'buy italian pasta online',
#     'types of pasta',
#     'cool cake hacks',
#     'best baking hacks',
#     'cake baking hacks',
#     'cookie baking hacks',
#     'diy baking hacks',
#     'baking life hacks',
#     'pillsbury baking hacks',
#     'baking hacks and tips',
#     'easy homemade bread recipe',
#     'easy white bread recipe for beginners',
#     'simple bread recipe',
#     'ingredients in bread',
#     'yeast bread recipes from scratch',
#     'homemade breads',
#     'basic bread recipe for beginners',
#     'bread machine recipes',
#     'simple cake recipes for beginners',
#     'easy cake recipe',
#     'homemade cake recipes from scratch',
#     'cake desserts recipes',
#     'all in one cake recipe',
#     'custom birthday cakes near me',
#     'cooking cake videos',
#     'all kinds of cake recipes',
#     'cry baby cookies history',
#     'homemade cookie recipes from scratch',
#     'easy homemade cookies',
#     'easy cookies with few ingredients',
#     'the absolute best cookie recipe ever',
#     'best easy cookies to make',
#     'basic cookie recipes from scratch',
#     'amazing cookie recipes']},
#   'interest_over_time': '{"schema":{"fields":[{"name":"date","type":"datetime"},{"name":"pancake","type":"integer"},{"name":"pasta","type":"integer"},{"name":"baking hacks","type":"integer"},{"name":"bread","type":"integer"},{"name":"cake","type":"integer"}],"primaryKey":["date"],"pandas_version":"0.20.0"},"data":[{"date":"2020-01-07T00:00:00.000Z
pasta":15,"baking hacks":0,"bread":33,"cake":37},{"date":"2020-02-07T00:00:00.000Z","pancake":4,"pasta":16,"baking hacks":0,"bread":34,"cake":40},{"date":"2020-02-08T00:00:00.000Z","pancake":7,"pasta":19,"baking hacks":0,"bread":38,"cake":52},{"date":"2020-02-09T00:00:00.000Z","pancake":9,"pasta":21,"baking hacks":0,"bread":42,"cake":53},{"date":"2020-02-10T00:00:00.000Z","pancake":3,"pasta":16,"baking hacks":0,"bread":33,"cake":38},{"date":"2020-02-11T00:00:00.000Z","pancake":3,"pasta":16,"baking hacks":0,"bread":32,"cake":39},{"date":"2020-02-12T00:00:00.000Z","pancake":3,"pasta":17,"baking hacks":0,"bread":32,"cake":41},{"date":"2020-02-13T00:00:00.000Z","pancake":4,"pasta":17,"baking hacks":0,"bread":31,"cake":45 ...
#  'Video_Chat_Platforms': {'related_queries': {'Google': ['what is houseparty',
#     'how to play games on houseparty',
#     'houseparty app chrome',
#     'zoom app',
#     'hangouts google login',
#     'zoom meeting',
#     'zoom party background',
#     'houseparty chrome',
#     'google hangouts meeting',
#     'virtual birthday party',
#     'google meet',
#     'houseparty fortnite',
#     'houseparty login',
#     'hangouts meet',
#     'google hangout',
#     'zoom download',
#     'house party',
#     'games on houseparty',
#     'zoom backgrounds',
#     'house party vs zoom',
#     'zoom party invite',
#     'join zoom',
#     'games on houseparty app',
#     'how to use google hangouts',
#     'how to host a zoom party',
#     'house',
#     'zoom stock',
#     'zoom mac',
#     'meet',
#     'zoom house party',
#     'zoom classroom',
#     'hangout',
#     'what is zoom',
#     'zoom party ideas',
#     'google hangouts chat',
#     'zoom birthday party ideas',
#     'houseparty',
#     'zoom login',
#     'netflix',
#     'join zoom meeting',
#     'what is google hangouts',
#     'how to use houseparty',
#     'zoom party games',
#     'google hangouts free',
#     'zoom dance party',
#     'houseparty app',
#     'party games to play on zoom',
#     'hangouts chat',
#     'google hangouts video',
#     'google meeting',
#     'google hangouts video chat',
#     'google call',
#     'get houseparty',
#     'google hangouts online',
#     'download houseparty',
#     'games to play on zoom',
#     'zoom background',
#     'google hangouts call',
#     'dodgers zoom party',
#     'how to do zoom',
#     'zoom account',
#     'houseparty app games',
#     'houseparty android',
#     'google hangouts how to',
#     'nike zoom',
#     'zoom online',
#     'zoom games',
#     'free zoom',
#     'zoom birthday party',
#     'houseparty games',
#     'change zoom background',
#     'how to have a zoom party',
#     'zoom video',
#     'how many people on houseparty',
#     'google classroom hangouts',
#     'meet google hangouts',
#     'hangouts app',
#     'houseparty on computer',
#     'how to use zoom',
#     'what is a zoom party',
#     'google zoom',
#     'google hangouts app',
#     'zoom call',
#     'how to zoom',
#     'house party app',
#     'google chat',
#     'what is houseparty app',
#     'zoom meetings',
#     'houseparty game',
#     'houseparty app safe',
#     'netflix party',
#     'zoom',
#     'houseparty online'],
#    'Bing': ['google hangouts youtube live',
#     'google hangouts sign in',
#     'google hangouts extension',
#     'instructions for using google hangouts',
#     'download google hangouts for pc',
#     'google play store app hangouts',
#     'group chat on google hangouts',
#     'google hangouts accounts',
#     'quarantine chat room',
#     'quarantine together dating app',
#     'quarantine together app',
#     'quarantine group chat names',
#     'quarantine chat app',
#     'quarantine dating app',
#     'lonely during covid',
#     'covid 19 chat',
#     'zoom party games',
#     'zoom party rooms id',
#     'zoom party for kids',
#     'zoom party themes',
#     'how to host a zoom party',
#     'virtual party game ideas',
#     'zoom party room',
#     'zoom party meeting rooms']},
#   'interest_over_time': '{"schema":{"fields":[{"name":"date","type":"datetime"},{"name":"Google hangouts","type":"integer"},{"name":"Zoom","type":"integer"},{"name":"QuarantineChat","type":"integer"},{"name":"HouseParty","type":"integer"},{"name":"Zoom Party","type":"integer"}],"primaryKey":["date"],"pandas_version":"0.20.0"},"data":[{"date":"2020-01-07T00:00:00.000Z","Google hangouts":0,"Zoom":4,"QuarantineChat":0,"HouseParty":0,"Zoom Party":0},{"date":"2020-01-08T00:00:00.000Z","Google hangouts":1,"Zoom":4,"QuarantineChat":0,"HouseParty":0,"Zoom Party":0},{"date":"2020-01-09T00:00:00.000Z","Google hangouts":0,"Zoom":4,"QuarantineChat":0,"HouseParty":0,"Zoom Party":0},{"date":"2020-01-10T00:00:00.000Z","Google hangouts":0,"Zoom":4,"QuarantineChat":0,"HouseParty":0,"Zoom Party":0},{"date":"2020-01-11T00:00:00.000Z","Google hangouts":0,"Zoom":3,"QuarantineChat":0,"HouseParty":0,"Zoom Party":0},{"date":"2020-01-12T00:00:00.000Z","Google hangouts":0,"Zoom":3,"QuarantineChat":0,"HouseParty":0,"Zoom Party":0},{"date":"2020-01-13T00:00:00.000Z","Google hangouts":1,"Zoom":4,"QuarantineChat":0,"HouseParty":0,"Zoom Party":0},{"date":"2020-01-14T00:00:00.000Z","Google hangouts":1,"Zoom":4,"QuarantineChat":0,"HouseParty":0,"Zoom Party":0},{"date":"2020-01-15T00:00:00.000Z","Google hangouts":0,"Zoom":4,"QuarantineChat":0,"HouseParty":0,"Zoom Party":0},{"date":"2020-01-16T00:00:00.000Z","Google hangouts":0,"Zoom":5,"QuarantineChat":0,"HouseParty":0,"Zoom Party":0},{"date":"2020-01-17T00:00:00.000Z","Google hangouts":1,"Zoom":4,"QuarantineChat":0,"HouseParty":0,"Zoom Party":0},{"date":"2020-01-18T00:00:00.000Z","Google hangouts":0,"Zoom":3,"QuarantineChat":0,"HouseParty":0,"Zoom Party":0},{"date":"2020-01-19T00:00:00.000Z","Google hangouts":0,"Zoom":3,"QuarantineChat":0,"HouseParty":0,"Zoom Party":0},{"date":"2020-01-20T00:00:00.000Z","Google hangouts":0,"Zoom":4,"QuarantineChat":0,"HouseParty":0,"Zoom Party":0},{"date":"2020-01-21T00:00:00.000Z","Google hangouts":1,"Zoom":5,"QuarantineChat":0,"HouseParty":0,"Zoom Party":0},{"date":"2020-01-22T00:00:00.000Z","Google hangouts":1,"Zoom":5,"QuarantineChat":0,"HouseParty":0,"Zoom Party":0},{"date":"2020-01-23T00:00:00.000Z","Google hangouts":1,"Zoom":4,"QuarantineChat":0,"HouseParty":0,"Zoom Party":0},{"date":"2020-01-24T00:00:00.000Z","Google hangouts":1,"Zoom":4,"QuarantineChat":0,"HouseParty":0,"Zoom Party":0},{"date":"2020-01-25T00:00:00.000Z","Google hangouts":0,"Zoom":3,"QuarantineChat":0,"HouseParty":0,"Zoom Party":0},{"date":"2020-01-26T00:00:00.000Z","Google hangouts":0,"Zoom":3,"QuarantineChat":0,"HouseParty":0,"Zoom Party":0},{"date":"2020-01-27T00:00:00.000Z","Google hangouts":1,"Zoom":4,"QuarantineChat":0,"HouseParty":0,"Zoom Party":0},{"date":"2020-01-28T00:00:00.000Z","Google hangouts":1,"Zoom":4,"QuarantineChat":0,"HouseParty":0,"Zoom Party":0},{"date":"2020-01-29T00:00:00.000Z","Google hangouts":1,"Zoom":4,"QuarantineChat":0,"HouseParty":0,"Zoom Party":0},{"date":"2020-01-30T00:00:00.000Z","Google hangouts":1,"Zoom":4,"QuarantineChat":0,"HouseParty":0,"Zoom Party":0},{"date":"2020-01-31T00:00:00.000Z","Google hangouts":1,"Zoom":4,"QuarantineChat":0,"HouseParty":0,"Zoom Party":0},{"date":"2020-02-01T00:00:00.000Z","Google hangouts":0,"Zoom":3,"QuarantineChat":0,"HouseParty":0,"Zoom Party":0},{"date":"2020-02-02T00:00:00.000Z","Google hangouts":0,"Zoom":3,"QuarantineChat":0,"HouseParty":0,"Zoom Party":0},{"date":"2020-02-03T00:00:00.000Z","Google hangouts":0,"Zoom":4,"QuarantineChat":0,"HouseParty":0,"Zoom Party":0},{"date":"2020-02-04T00:00:00.000Z","Google hangouts":1,"Zoom":5,"QuarantineChat":0,"HouseParty":0,"Zoom Party":0},{"date":"2020-02-05T00:00:00.000Z","Google hangouts":1,"Zoom":4,"QuarantineChat":0,"HouseParty":0,"Zoom Party":0},{"date":"2020-02-06T00:00:00.000Z","Google hangouts":1,"Zoom":5,"QuarantineChat":0,"HouseParty":0,"Zoom Party":0},{"date":"2020-02-07T00:00:00.000Z","Google hangouts":1,"Zoom":4,"QuarantineChat":0,"HouseParty":0,"Zoom Party":0},{"date":"2020-02 ...
#  'Live_Virtual_Performance': {'related_queries': {'Google': ['billie eilish tour',
#     'billie eilish nude',
# ...
#  'Tiktok_Meme': {'related_queries': {'Google': ['high school musical',
#     'highschool musical cast',
#     'best dance workouts',
#     'free dance workouts',
#     'shaun t dance workouts',
#     'highschool musical the musical',
#     'best youtube dance workouts',
#     'beachbody',
#     'highschool musical the series',
#     'highschool musical songs'],
#    'Bing': ['high school musical 2019 cast',
#     'high school musical 4 release',
#     'high school musical full movie',
#     'cast of high school musical',
#     'good musicals for high schoolers',
#     'high school musical series cast',
#     'high school musical free full',
#     'high school musical songs',
#     'dance for exercise',
#     'youtube video zumba dance workout',
#     'dance videos for exercise',
#     'youtube exercise videos workout',
#     'free dance exercise videos online',
#     'youtube dance exercise workout',
#     'free dance exercise videos',
#     'best youtube dance workout videos',
#     'solo dance martin jensen download',
#     'han solo dance',
#     'dance solo costumes',
#     'solo dance songs for girls',
#     'solo dance 1 hour',
#     'lyrical songs for dance solos',
#     'jazz dance solo song ideas',
#     'solo dance martin jensen',
#     'themed dinner nights',
#     'themed dinner parties',
#     'themed dinner menu',
#     'themed dinner party menu ideas',
#     'party menu ideas',
#     'dinner party themes for adults',
#     'best dinner party menu ever',
#     'menu for italian themed dinner',
#     'tiktok distance dance',
#     'distance dance song',
#     'distance dance charli',
#     'omarion distance video',
#     'social distance dance party',
#     'social distance dancing',
#     'charlie damelio coronavirus',
#     'p&amp;g donation coronavirus']},
#   'interest_over_time': '{"schema":{"fields":[{"name":"date","type":"datetime"},{"name":
"dance workouts":0,"solo dance":29,"themed dinners":0,"distance dance":0},{"date":"2020-01-30T00:00:00.000Z","highschool musical":37,"dance workouts":15,"solo dance":44,"themed dinners":0,"distance dance":15},{"date":"2020-01-31T00:00:00.000Z","highschool musical":15,"dance workouts":29,"solo dance":15,"themed dinners":0,"distance dance":0},{"date":"2020-02-01T00:00:00.000Z","highschool musical":67,"dance workouts":17,"solo dance":25,"themed dinners":0,"distance dance":17},{"date":"2020-02-02T00:00:00.000Z","highschool musical":17,"dance workouts":17,"solo dance":17,"themed dinners":0,"distance dance":0},{"date":"202 ...
#  'Virtual_Workouts': {'related_queries': {'Google': ['hiit workouts',
#     'home gym equipment',
#     'gold gym',
#     'gym coronavirus',
#     'hiit training workout',
#     'full body hiit workout',
#     'gym equipment',
#     'the gym',
#     'hot yoga',
#     'open gym',
#     'body gym',
#     'dancing with stars',
#     'corepower yoga',
#     'what is hiit workout',
#     'salsa dancing',
#     'yoga near me',
#     'dancing classes',
#     'home hiit workout',
#     'dancing dog',
#     'gyms',
#     '10 minute hiit workout',
#     'boxing gym',
#     'hiit cardio',
#     'lenovo yoga',
#     'tabata hiit workout',
#     'hiit cardio workout',
#     'planet fitness',
#     'what is a hiit workout',
#     'dancing baby',
#     'online yoga',
#     'ab toning workout',
#     'yoga mat',
#     'hiit workout women',
#     'youtube hiit workout',
#     'dancing in the moonlight',
#     'best gym',
#     'hiit full body workout',
#     'line dancing',
#     'gym shoes',
#     'girl dancing',
#     'my gym',
#     '30 minute hiit workout',
#     'yoga pose',
#     'dancing meme',
#     'pole dancing',
#     'flirty dancing',
#     'hiit bike workout',
#     '20 minute hiit workout',
#     'hiit exercises',
#     'cosmic yoga',
#     'kids gym',
#     'yoga pants',
#     'arm toning workout',
#     'power yoga',
#     'pole dancing classes',
#     'dancing queen',
#     'upper body hiit workout',
#     'yoga poses',
#     'gym shark',
#     'rock gym',
#     'hiit at home workout',
#     'yoga workout',
#     'dancing dolls',
#     'cosmic kids yoga',
#     'alo yoga',
#     'school gym',
#     'yoga classes',
#     'dirty dancing',
#     'kids yoga',
#     'slow dancing in the dark',
#     'dancing in the dark',
#     'climbing gym',
#     'country dancing',
#     'free yoga',
#     'golds gym',
#     'yoga with adriene',
#     'adriene yoga',
#     'hiit workout routine',
#     'yoga class',
#     'bikram yoga',
#     'beginners yoga',
#     'gym near me',
#     'dancing gif',
#     'leg toning workout',
#     'dancing with the stars',
#     'ab hiit workout',
#     'dancing near me',
#     'total gym',
#     'yoga studio',
#     'best hiit workout',
#     'dancing songs',
#     'hiit running workout',
#     'what is yoga',
#     'yoga youtube',
#     'home gym',
#     'hiit workout plan',
#     'hiit treadmill workout',
#     'fitness gym',
#     'gym membership',
#     'little gym',
#     'dancing on my own',
#     'kids dancing',
#     'belly dancing'],
#    'Bing': ['24 hours gym',
#     'planet fitness',
#     '$10 a month gym membership',
#     'cheapest gyms near me',
#     'gold&#39;s gym exercise equipment website',
#     'gold&#39;s gym home equipment',
#     '24 hour gyms near me',
#     'gyms near me',
#     'morning yoga with adriene youtube',
#     'how to start yoga',
#     'yoga for beginners',
#     'yoga near me',
#     'yoga with adrienne youtube channel',
#     'yoga poses',
#     'youtube yoga videos',
#     'why yoga is beneficial',
#     'the dancing baby',
#     'dancing man video',
#     'street dancing video',
#     'youtube people dancing',
#     'dancing with stars',
#     'the dancing girls',
#     'dancing on air',
#     'youtube dancing with the stars',
#     'toning workout for women',
#     'toning exercises for beginners',
#     'toning workout video',
#     'beginner toning exercises for women',
#     'at home exercise routines printable',
#     'printable exercise program for beginners',
#     'printable toning workouts for women',
#     'female workout routines for toning',
#     '7 minute workout printable version',
#     'hiit workout pdf',
#     'printable hiit workouts for women',
#     'printable hiit workout for men',
#     '20 minute hiit workout plan',
#     'hiit 100 workout pdf',
#     '30 minute printable hiit workout',
#     'hiit workout for beginners']},
#   'interest_over_time': '{"schema":{"fields":[{"name":"date","type":"datetime"},{"name":"Gym","type":"integer"},{"name":"Yoga","type":"integer"},{"name":"Dancing","type":"integer"},{"name":"Toning workout","type":"integer"},{"name":"HIIT workout","type":"integer"}],"primaryKey":["date"],"pandas_version":"0.20.0"},"data":[{"date":"2020-01-07T00:00:00.000Z","Gym":63,"Yoga":63,"Dancing":27,"Toning workout":0,"HIIT workout":1},{"date":"2020-01-08T00:00:00.000Z","Gym":60,"Yoga":62,"Dancing":25,"Toning workout":0,"HIIT workout":1},{"date":"2020-01-09T00:00:00.000Z","Gym":55,"Yoga":59,"Dancing":28,"Toning workout":0,"HIIT workout":1},{"date":"2020-01-10T00:00:00.000Z","Gym":55,"Yoga":56,"Dancing":26,"Toning workout":0,"HIIT workout":1},{"date":"2020-01-11T00:00:00.000Z","Gym":64,"Yoga":62,"Dancing":30,"Toning workout":0,"HIIT workout":1},{"date":"2020-01-12T00:00:00.000Z","Gym":61,"Yoga":63,"Dancing":30,"Toning workout":0,"HIIT workout":0},{"date":"2020-01-13T00:00:00.000Z","Gym":58,"Yoga":60,"Dancing":23,"Toning workout":0,"HIIT workout":1},{"date":"2020-01-14T00:00:00.000Z","Gym":57,"Yoga":58,"Dancing":24,"Toning workout":0,"HIIT workout":1},{"date":"2020-01-15T00:00:00.000Z","Gym":58,"Yoga":57,"Dancing":25,"Toning workout":0,"HIIT workout":1},{"date":"2020-01-16T00:00:00.000Z","Gym":55,"Yoga":55,"Dancing":27,"Toning workout":0,"HIIT workout":1},{"date":"2020-01-17T00:00:00.000Z","Gym":53,"Yoga":54,"Dancing":27,"Toning workout":0,"HIIT workout":1},{"date":"2020-01-18T00:00:00.000Z","Gym":64,"Yoga":59,"Dancing":34,"Toning workout":0,"HIIT workout":1},{"date":"2020-01-19T00:00:00.000Z","Gym":61,"Yoga":61,"Dancing":33,"Toning workout":0,"HIIT workout":1},{"date":"2020-01-20T00:00:00.000Z","Gym":72,"Yoga":64,"Dancing":26,"Toning workout":0,"HIIT workout":1},{"date":"2020-01-21T00:00:00.000Z","Gym":60,"Yoga":60,"Dancing":25,"Toning workout":0,"HIIT workout":1},{"date":"2020-01-22T00:00:00.000Z","Gym":55,"Yoga":57,"Dancing":24,"Toning workout":0,"HIIT workout":1},{"date":"2020-01-23T00:00:00.000Z","Gym":55,"Yoga":54,"Dancing":26,"Toning workout":0,"HIIT workout":1},{"date":"2020-01-24T00:00:00.000Z","Gym":52,"Yoga":52,"Dancing":27,"Toning workout":0,"HIIT workout":1},{"date":"2020-01-25T00:00:00.000Z","Gym":65,"Yoga":59,"Dancing":29,"Toning workout":0,"HIIT workout":1},{"date":"2020-01-26T00:00:00.000Z","Gym":56,"Yoga":53,"Dancing":37,"Toning workout":0,"HIIT workout":1},{"date":"2020-01-27T00:00:00.000Z","Gym":51,"Yoga":54,"Dancing":25,"Toning workout":0,"HIIT workout":1},{"date":"2020-01-28T00:00:00.000Z","Gym":54,"Yoga":53,"Dancing":27,"Toning workout":0,"HIIT workout":1},{"date":"2020-01-29T00:00:00.000Z","Gym":53,"Yoga":54,"Dancing":25,"Toning workout":0,"HIIT workout":1},{"date":"2020-01-30T00:00:00.000Z","Gym":52,"Yoga":54,"Dancing":26,"Toning workout":0,"HIIT workout":1},{"date":"2020-01-31T00:00:00.000Z","Gym":50,"Yoga":51,"Dancing":24,"Toning workout":0,"HIIT workout":1},{"date":"2020-02-01T00:00:00.000Z","Gym":59,"Yoga":57,"Dancing":30,"Toning workout":0,"HIIT workout":1},{"date":"2020-02-02T00:00:00.000Z","Gym":53,"Yoga":54,"Dancing":31,"Toning workout":0,"HIIT workout":0},{"date":"2020-02-03T00:00:00.000Z","Gym":46,"Yoga":47,"Dancing":37,"Toning workout":0,"HIIT workout":1},{"date":"2020-02-04T00:00:00.000Z","Gym":51,"Yoga":53,"Dancing":30,"Toning workout":0,"HIIT workout":1},{"date":"2020-02-05T00:00:00.000Z","Gym":52,"Yoga":52,"Dancing":27,"Toning workout":0,"HIIT workout":1},{"date":"2020-02-06T00:00:00.000Z","Gym":49,"Yoga":51,"Dancing":26,"Toning workout":0,"HIIT workout":1},{"date":"2020-02-07T00:00:00.000Z","Gym":50,"Yoga":50,"Dancing":28,"Toning workout":0,"HIIT workout":1},{"date":"2020-02-08T00:00:00.000Z","Gym":60,"Yoga":53,"Dancing":32,"Toning workout":0,"HIIT workout":1},{"date":"2020-02-09T00:00:00.000Z","Gym":58,"Yoga":56,"Dancing":30,"Toning workout":0,"HIIT workout":1},{"date":"2020-02-10T00:00:00.000Z","Gym":51,"Yoga":52,"Dancing":25,"Toning workout":0,"HIIT workout":1},{"date":"2020-02-11T00:00:00.000Z","G ...

# %%
#WRITE OUT THE JSON OBJECT CREATED
import json

with open('DSCI_Project_Output.json', 'w', encoding='utf-8') as f:
    json.dump(final_json, f, ensure_ascii=False, indent=4)

# %% [markdown]
# ## Code to interact with final output

# %%
# FUNCTION TO LIST ALL THE TOPIC NAMES
def get_topic_names(data):
    return([i for i in data])

get_topic_names(final_json)
# Out:
# ['Streaming',
#  'Exercises',
#  'HBO_Shows',
#  'Virtual_Games',
#  'Cooking',
#  'Video_Chat_Platforms',
#  'Live_Virtual_Performance',
#  'Cameo',
#  'Social_Media',
#  'TikTok',
#  'Instagram',
#  'Tiktok_Meme',
#  'Virtual_Workouts']

# %%
# FUNCTION THAT RETURNS A DATAFRAME OF TIMESERIES DATA FOR A GIVEN TOPIC NAME
def interest_over_time(Topic_name):
    
    df = pd.read_json(final_json[Topic_name]["interest_over_time"], orient='table')

    return(df)

interest_over_time('Streaming')
# Out:
#             Quibi  HBO  Netflix  Free Documentries  Free Shows
# date
# 2020-01-07      0    4       50                  0           0
# 2020-01-08      0    4       46                  0           0
# 2020-01-09      0    4       47                  0           0
# 2020-01-10      0    4       47                  0           0
# 2020-01-11      0    6       60                  0           0
# ...           ...  ...      ...                ...         ...
# 2020-05-30      0   16       56                  0           0
# 2020-05-31      0   13       58                  0           0
# 2020-06-01      0   11       46                  0           0
# 2020-06-02      0    9       45                  0           0
# 2020-06-03      0    8       46                  0           0
#
# [149 rows x 5 columns]

# %%
#FUNCTION THAT RETURNS TWO LISTS OF RELATED QUEIRES IN THE ORDER GOOGLE, BING
def related_queries(Topic_name) :
    x = final_json[Topic_name]["related_queries"]
    Google = x['Google']
    Bing = x['Bing']
    return(Google, Bing)

related_queries('Streaming')
# Out:
# (['quibi movie',
#   'free netflix',
#   'hbo login',
#   'good movies on netflix',
#   'the stranger',
#   'quibi reno 911',
#   'quibi t mobile',
#   'quibi price',
#   'netflix outer banks',
#   'hulu',
#   'new hbo',
#   'hbo shows',
#   'you netflix',
#   'free tv shows online',
#   'the outsider',
#   'netflix shows',
#   'hulu hbo',
#   'quibi dummy',
#   'netflix new movies',
#   'tv shows for free',
#   'broadway shows',
#   'what is quibi',
#   'best netflix movies',
#   'good netflix movies',
#   'netflix stock',
#   'netflix movies 2020',
#   'quibi review',
#   'hulu shows',
#   'hollywood netflix',
#   'netflix login',
#   'netflix account',
#   'watch shows free',
#   'hbo amazon prime',
#   'tv shows free',
#   'free shows online',
#   'netflix movies',
#   'quibi ipo',
#   'hbo max',
#   'quibi app',
#   'movies on hbo',
#   'new on netflix',
#   'watch shows for free',
#   'shows on netflix',
#   'dummy',
#   'free movies',
#   'free movies online',
#   'watch shows online free',
#   'hbo now',
#   'tv shows',
#   'survive quibi',
#   'hbo movies',
#   'reno 911',
#   'quibi streaming',
#   'hbo schedule',
#   'best movies on netflix',
#   'outer banks',
#   'the outsider hbo',
#   'watch free movies',
#   'quibi stock',
#   'quibi free',
#   'quibi commercial',
#   'hbo go',
#   'tv shows online',
#   '123movies',
#   'watch free tv shows',
#   'quibi tv',
#   'free shows and movies',
#   'hbo free shows',
#   'most dangerous game',
#   'amazon hbo',
#   'quibi the stranger',
#   'hbo show',
#   'hbo free',
#   'movies on netflix',
#   'you on netflix',
#   'hbo streaming',
#   'watch free tv shows online',
#   'quibi stock price',
#   'outsider hbo',
#   'free broadway shows',
#   'showtime',
#   'quibi shows',
#   'stream tv shows free',
#   'hbo',
#   'hbo on hulu',
#   'watch hbo',
#   'netflix series',
#   'best hbo movies',
#   'quibi movies',
#   'best shows on netflix',
#   'quibi most dangerous game',
#   'hbo run',
#   'hbo series',
#   'best netflix shows',
#   'quibi cost',
#   'free movies and tv shows',
#   'netflix party'],
#  ['ubi internet banking',
#   'qui ubi banca imprese',
#   'qui ubi login',
#   'ubi banca qui ubi',
#   'qui ubi france',
#   'qui ubi banca online',
#   'ubi banca home banking',
#   'ubi banca internet banking',
#   'hbo tv schedule tonight',
#   'hbo now tv code',
#   'free hbo',
#   'is hbo free this week',
#   'watch free hbo online channel',
#   'hbo go app free',
#   'hbo today schedule',
#   'hbo new movies tonight',
#   'history channel documentaries free online',
#   'pbs documentaries online free',
#   'pbs history documentaries free online',
#   'youtube free documentaries full length',
#   'free american history documentaries',
#   'watch free full length documentaries',
#   'discovery channel documentaries free online',
#   'free documentaries youtube history channel',
#   'watch free live stream movies',
#   'watch tv programs free online',
#   'old tv shows free youtube',
#   'free shows online full episodes',
#   'watch full tv episodes for free online',
#   'free online tv show websites',
#   'tv shows online for free',
#   'free tv episodes online no registration'])

# %% [markdown]
# #### Tables and figures indicating the size and variety present in your data

# %%
## amount of keys
print("Amount of Topics:", len(list(final_json.keys())))

## amount of items in keys
print("Amount of items in Topics:", sum( [ len(i) for i in final_json.values()]) )

# interest over time data has the following dtypes 
interest_over_time('Streaming').reset_index().dtypes
# Out:
# Amount of Topics: 13
# Amount of items in Topics: 26
# date                 datetime64[ns]
# Quibi                         int64
# HBO                           int64
# Netflix                       int64
# Free Documentries             int64
# Free Shows                    int64
# dtype: object
