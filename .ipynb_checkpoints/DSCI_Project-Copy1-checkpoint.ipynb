# %%
Topics = {
"Streaming" : ["Quibi", "HBO", "Netflix", "Free Documentries", "Free Shows"],
"Exercises" : ["Yoga", "Walking", "Running", "Meditate", "Bicycle riding"],
"HBO_Shows" : ["Succession","True Blood","The Sopranos","Veep","The Wire"],
"Virtual_Games" : ["Animal Crossing: New Horizons", "Club Penguin", "Monopoly", "Mario Kart Tour","Words With Friends"],
"Cooking" : ["pancake", "pasta", "baking hacks", "bread", "cake", "cookie"],
"Video_Chat_Platforms" : ["Google hangouts", "Zoom", "QuarantineChat", "HouseParty","Zoom Party"],
"Live_Virtual_Performance" : ["Billie Eilish","BTS", "Dua Lipa", "Sophia Ankel"],
"Cameo" : ["Steven Galanis", "Rachel Dratch", "Mandy Moore", "Restaurant Workers' Relief Fund"],
"Social_Media" : ["Memes", "TikTok", "Instagram"],
"TikTok" : ["airplane","Hibachi grill","Hooters", "Ciara", "Usher", "Jennifer Lopez"],
"Instagram" : ["memes", "video chat", "makeup tutorials", "distance dance", "working_from_home"],
"Tiktok_Meme" : ["highschool musical", "dance workouts", "solo dance", "themed dinners", "distance dance"],
"Virtual_Workouts" : ["Gym", "Yoga", "Dancing", "Toning workout", "HIIT workout"],
}

# %%
import os
import pandas as pd
import pprint
from datetime import datetime, timedelta
from pytrends.request import TrendReq
import numpy as np

# %%
pytrends = TrendReq(hl='en-US', tz=360)

date_range = (datetime.today() - timedelta(150)).strftime('%Y-%m-%d') + " " + datetime.today().strftime('%Y-%m-%d')

# %%
#function to iterate over a list in batches of 5 & retun a list of "lists with 5 elements"
def keyword_list_creator(keyword_list):
    new_list = []
    for i in range(int(len(keyword_list)/5)+1):
        new_list.append(keyword_list[i*5 : (i+1)*5])
    return(new_list)

# %%
#function to return dataframe for a keyword list of 5 elements
def trend_df(channels):
    
    pytrends.build_payload(channels, cat=0,timeframe = date_range , geo='US', gprop='')

    interest_over_time = pytrends.interest_over_time().drop("isPartial",axis = 1)
    try:
        rel_queries = get_google_rel_queries(pytrends.related_queries())
    except:
        print("issue with rel_queries")
        rel_queries = []
    return(interest_over_time, rel_queries)

#function to return dataframe for a keyword list of more than 5 elements
def create_df(topic_name):
    
    keywords_list = keyword_list_creator(topic_name)
    
    if len(keywords_list[-1]) == 0:
        keywords_list = keywords_list[:-1]

    for i in range(len(keywords_list)):
        if i ==0:
            df, google_rel_queries = trend_df(keywords_list[i])
        else:
            df1, google_rel_queries_1 = trend_df(keywords_list[i])
            df = pd.concat([df, ], axis=1)
            google_rel_queries += google_rel_queries_1


    return(df,google_rel_queries)

# %%
# create_df(["Quibi", "HBO", "Netflix", "Free Documentries", "Free Shows"])

# %%
def get_google_rel_queries(google_rel_queries):
    rel_queries = []

    for i in google_rel_queries.keys():
#         print(i)
        try :
            rel_queries += list(google_rel_queries[i]['top']["query"][:])
        except:
            continue        

    rel_queries = list(set(rel_queries))
    return(rel_queries)

# %%
# create_trends_df(Virtual_Games)

# %%
for i in Topics.keys():
    print(i)
    try:
        print(create_df(Topics[i]))
    except:
        
        continue
# Out:
# Streaming
# (            Quibi  HBO  Netflix  Free Documentries  Free Shows
# date
# 2019-12-31      0    5       65                  0           0
# 2020-01-01      0    6       81                  0           0
# 2020-01-02      0    5       74                  0           0
# 2020-01-03      0    5       64                  0           0
# 2020-01-04      0    6       72                  0           0
# ...           ...  ...      ...                ...         ...
# 2020-05-24      1   10       68                  0           0
# 2020-05-25      1   11       67                  0           0
# 2020-05-26      1   10       54                  0           0
# 2020-05-27      1   35       51                  0           0
# 2020-05-28      1   26       51                  0           0
#
# [150 rows x 5 columns], ['hbo run', 'most dangerous game quibi', 'hbo max', 'amazon prime hbo', 'quibi commercial', 'the stranger', 'the outsider', 'hbo on hulu', 'best on netflix', 'quibi on tv', 'hulu shows', 'quibi dummy', 'free shows online', 'showtime', 'good netflix movies', 'netflix shows', 'hbo the outsider', 'best hbo movies', 'hbo show', 't mobile quibi', 'outsiders', 'free movies and tv shows', 'quibi firestick', 'shows on netflix', 'quibi tv', 'good movies on netflix', 'amazon hbo', 'hulu hbo', 'what is quibi', 'tv shows', 'best netflix shows', 'hbo now', 'free netflix', 'you on netflix', 'dummy', 'tv shows free', 'shows on amazon prime', 'you netflix', 'quibi price', 'hbo movies', 'hbo free', 'survive quibi', 'quibi review', 'hbo shows', 'hulu', 'tv shows to watch', 'quibi app', 'netflix stock', 'quibi shows', 'netflix movies 2020', 'free movies', 'watch shows online free', 'most dangerous game', 'watch free tv shows online', 'quibi roku', 'hbo streaming', 'outsiders hbo', 'netflix account', 'netflix series', 'hbo series', 'hollywood netflix', 'hbo free shows', 'broadway shows', 'stream tv shows free', 'broadway shows free', 'netflix login', 'quibi stock', 'best netflix movies', 'watch free movies', 'reno 911', 'movies on hbo', 'outer banks netflix', 'netflix movies', 'free movies and shows', 'outer banks', 'hbo', 'new netflix movies', 'movies on netflix', 'outsider hbo', 'quibi movies', 'new on netflix', 'free movies online', 'quibi streaming', 'best movies on netflix', 'quibi cost', 'free tv shows online', 'hbo go', 'quibi the stranger', 'free hbo', 'netflix party', '123movies', 'quibi movie', 'watch tv shows free', 'hbo schedule', 'hbo login', 'quibi reno 911', 'watch tv shows for free'])
# Exercises
# (            Yoga  Walking  Running  Meditate  Bicycle riding
# date
# 2019-12-31    56       39       70         1               0
# 2020-01-01    59       44       74         1               0
# 2020-01-02    74       43       76         1               0
# 2020-01-03    69       42       69         1               0
# 2020-01-04    68       44       76         1               0
# ...          ...      ...      ...       ...             ...
# 2020-05-24    46       53       92         1               0
# 2020-05-25    45       56       92         1               0
# 2020-05-26    41       50       87         1               0
# 2020-05-27    41       46       85         1               0
# 2020-05-28    43       42       84         1               0
#
# [150 rows x 5 columns], ['when is the best time to meditate', 'yoga class', 'beginners yoga', 'running shoe', 'ways to meditate', 'brooks running shoes', 'how do you meditate', 'people walking', 'trail running', 'best time to meditate', 'cosmic yoga', 'walking stick', 'learn to meditate', 'hot yoga', 'dog walking', 'walking pneumonia', 'adriene yoga', 'walking shoes', 'running boards', 'mens running shoes', 'nike running shoes', 'bikram yoga', 'new balance', 'how to learn to meditate', 'rick walking dead', 'yoga classes', 'yoga studio', 'the walking dead season 10', 'on running', 'corepower yoga', 'the walking dead cast', 'how to meditate for anxiety', 'brooks shoes', 'meditation definition', 'what is yoga', 'nike shoes', 'yoga pose', 'walking foot', 'womens running shoes', 'meditation', 'life is like riding a bicycle', 'yoga mat', 'kids yoga', 'walking calories burned', 'what is meditation', 'walking video', 'fear the walking dead', 'running shorts', 'biden running mate', 'best shoes for walking', 'running store', 'brooks running', 'online yoga', 'yoga with adriene', 'how to meditate for beginners', 'how to meditate properly', 'best running shoes', 'walking dead cast', 'walking exercise', 'brooks', 'yoga poses', 'walking tall', 'how do i meditate', 'asics', 'walking trails', 'meditate on the word', 'walking dead', 'pneumonia', 'free yoga', 'nike running', 'asics running', 'how long should i meditate', 'cosmic kids yoga', 'who is running for president', 'mediate', 'how to meditate', 'walking trails near me', 'yoga pants', 'walking company', 'lenovo yoga', 'meditate lyrics', 'how to meditate at home', 'yoga near me', 'yoga workout', 'best walking shoes', 'on running shoes', 'alo yoga', 'season 10 walking dead', 'how long to meditate', 'learning to meditate', 'running shoes', 'meditate definition', 'running man', 'meditate meaning', 'why meditate', 'how to meditate reddit', 'the walking dead', 'power yoga', 'walking trail', 'youtube yoga', 'running for president'])
# HBO_Shows
# (            Succession  True Blood  The Sopranos  Veep  The Wire
# date
# 2019-12-31           7           3             2     1        11
# 2020-01-01           7           3             2     1         9
# 2020-01-02           8           3             2     1        10
# 2020-01-03           7           3             2     1        11
# 2020-01-04           8           3             2     1        11
# ...                ...         ...           ...   ...       ...
# 2020-05-24           7           5             3     2        16
# 2020-05-25           6           6             4     2        16
# 2020-05-26           8           4             3     1        14
# 2020-05-27           6           4             3     1        13
# 2020-05-28           5           5             3     1        13
#
# [150 rows x 5 columns], ['imdb true blood', 'under the wire', 'the sopranos reddit', 'ecological succession', 'veep seasons', 'the high wire', 'walmart the wire', 'veep season 1', 'succession season 2', 'succession hbo', 'over the wire', 'true blood sookie', 'how many seasons of the sopranos', 'the wire season 3', 'the sopranos ending', 'true blood books', 'amazon the wire', 'secondary succession', 'the sopranos netflix', 'dan egan veep', 'primary and secondary succession', 'cast of true blood', 'the wire', 'veep season 3', 'sue veep', 'daily caller', 'tara true blood', 'the wire series', 'cast of the sopranos', 'cast of veep', 'sopranos season 6', 'wire cast', 'paulie the sopranos', 'succession season 1', 'the sopranos season 1', 'michael the wire', 'succession show', 'succession of president', 'cast true blood', 'omar the wire', 'pioneer species', 'veep season 6', 'true blood episodes', 'president succession', 'veep episodes', 'anna paquin', 'true blood godric', 'catherine veep', 'daily wire', 'primary succession', 'the sopranos cast', 'lafayette', 'veep cast', 'jessica true blood', 'bill true blood', 'eric true blood', 'succession definition', 'sam true blood', 'pussy the sopranos', 'the sopranos movie', 'veep season 7', 'line of succession', 'season 2 true blood', 'through the wire', 'succession cast', 'the sopranos episodes', 'jonah veep', 'gary veep', 'season 4 the wire', 'veep characters', 'the sopranos season 2', 'what is succession', 'tom james veep', 'succession planning', 'barbed wire', 'the daily wire', 'dan veep', 'what is secondary succession', 'veep imdb', 'omar', 'watch true blood', 'jason true blood', 'the wire show', 'veep show', 'the daily caller', 'veep definition', 'amy veep', 'all the wire', 'true blood season 5', 'the veep', 'veep review', 'the sopranos season 6', 'in succession', 'sopranos season 3', 'veep season 5', 'what is primary succession', 'primary succession and secondary succession', 'order of succession', 'annabella sciorra', 'the sopranos season 4', 'presidential succession', 'true blood season 6', 'lafayette true blood', 'season 1 the wire', 'true blood seasons', 'the sopranos season 5', 'walmart wire', 'hbo', 'the sopranos season 3', 'season 3 succession', 'true blood season 3', 'veep season 8', 'adriana the sopranos', 'the succession', 'watch the wire', 'true blood season 1', 'hbo veep', 'sopranos cast', 'christopher the sopranos', 'sopranos movie', 'true blood season 2', 'the wire cast', 'the wire season 2', 'sopranos season 2', 'true blood season 7'])
# Virtual_Games
# (            Animal Crossing: New Horizons  Club Penguin  Monopoly  \
# date
# 2019-12-31                              0             2         7
# 2020-01-01                              1             2        12
# 2020-01-02                              1             2         7
# 2020-01-03                              1             2         6
# 2020-01-04                              1             2         7
# ...                                   ...           ...       ...
# 2020-05-24                             19             2         6
# 2020-05-25                             19             2         7
# 2020-05-26                             16             2         5
# 2020-05-27                             15             2         4
# 2020-05-28                             15             2         4
#
#             Mario Kart Tour  Words With Friends
# date
# 2019-12-31                1                   7
# 2020-01-01                1                   7
# 2020-01-02                1                   6
# 2020-01-03                1                   7
# 2020-01-04                1                   8
# ...                     ...                 ...
# 2020-05-24                0                   6
# 2020-05-25                0                   8
# 2020-05-26                0                   6
# 2020-05-27                0                   7
# 2020-05-28                0                   7
#
# [150 rows x 5 columns], ['webkinz', 'words with friends cheat with screenshot', 'disney club penguin', 'mario kart tour friends', 'animal jam', 'words with friends scrabble', 'animal crossing qr codes', 'words with friends generator', 'friends with words cheat', 'words with friends word generator', 'club penguin missions', 'animal crossing new leaf', 'new club penguin', 'mario kart world tour', 'monopoly app', 'penguin game', 'monopoly man', 'what is a monopoly', 'online monopoly', 'monopoly board', 'club penguin names', 'nintendo switch', 'club penguin codes', 'amiibo new horizons', 'thwomp mario kart tour', 'play monopoly online', 'online games', 'monopoly game board', 'club penguin rewritten', 'games', 'animal crossing new horizons amiibo', 'reddit animal crossing new horizons', 'animal crossing new horizons flowers', 'monopoly rules', 'words with friends helper', 'words with friends dictionary', 'words with friends finder', 'animal crossing amiibo', 'monopoly deal', 'what is club penguin', 'mario kart tour cheats', 'reddit mario kart tour', 'monopoly definition', 'puffles club penguin', 'play club penguin', 'in monopoly', 'words with friends app', 'play words with friends', 'monopoly game', 'animal crossing new horizons price', 'club penguin shut down', 'club penguin back', 'monopoly money', 'mario kart tour twitter', 'qr codes animal crossing new horizons', 'monopoly games', 'club penguin codes 2020', 'friends monopoly', 'mario kart tour yoshi tour', 'animal crossing new horizons fruit', 'mario kart tour wiki', 'what is monopoly', 'animal crossing new horizons designs', 'mario kart tour characters', 'words with friends help', 'word finder', 'words with friends cheats', 'nintendo', 'animal crossing switch', 'words with friends board', 'monopoly pieces', 'words with friends screenshot cheat', 'mario kart tour kadomatsu', 'animal crossing new horizons house', 'is mario kart tour multiplayer', 'club penguin online', 'club penguin online codes', 'kadomatsu', 'club penguin login', 'clubpenguin', 'new horizons villagers', 'monopoly safeway', 'how to play monopoly', 'mario kart tour news', 'words with friends screenshot', 'club penguin island', 'word finder words with friends', 'animal crossing new horizons new villagers', 'mario kart tour tips', 'words for words with friends', 'monopoly money start', 'animal crossing new horizons guide', 'animal crossing new horizons fish', 'mario kart tour multiplayer', 'monopoly plus', 'animal crossing fish', 'poptropica', 'mario kart tour datamine', 'word with friends', 'villagers animal crossing new horizons', 'club penguin code', 'reddit animal crossing', 'monopoly mcdonalds', 'how much money in monopoly', 'words with friends cheat words', 'amiibo', 'cheat with words with friends', 'words with friends cheat 2', 'help with words with friends', 'scrabble', 'animal crossing new horizons switch', 'monopoly cards', 'words with friends cheat with board', 'animal crossing villagers', 'club penguin rewritten codes', 'sidesteppers mario kart tour', 'what is a standard race in mario kart tour', 'how much monopoly money'])
# Cooking
# (            pancake  pasta  baking hacks  bread  cake
# date
# 2019-12-31        5     18             0     38    48
# 2020-01-01        9     17             0     41    42
# 2020-01-02        4     17             0     34    35
# 2020-01-03        4     17             0     33    38
# 2020-01-04        7     20             0     38    44
# ...             ...    ...           ...    ...   ...
# 2020-05-24       10     24             0     53    63
# 2020-05-25        8     24             0     48    59
# 2020-05-26        4     18             0     37    44
# 2020-05-27        5     18             0     37    43
# 2020-05-28        5     19             0     39    46
#
# [150 rows x 5 columns], ['pesto pasta', 'coffee cake', 'lemon pasta', 'shrimp pasta', 'bread recipes', 'chicken pasta', 'garlic bread', 'panera bread menu', 'homemade bread', 'french bread', 'pasta sauce', 'cake bakery', 'pancake near me', 'pancakes', 'chicken pasta recipes', 'cake recipes', 'pancake recipes', 'birthday cake', 'panera menu', 'banana bread', 'cajun pasta', 'pasta recipe', 'keto bread', 'spaghetti', 'white bread', 'how to make bread', 'pasta near me', 'how to make pasta', 'easy pancake recipe', 'pasta noodles', 'pancake breakfast', 'chicken recipes', 'pancake syrup', 'baking bread', 'pancake cake', 'pasta with chicken', 'cakes', 'yeast', 'cheese cake', 'strawberry cake', 'ihop', 'pancakes recipe', 'carrot cake', 'pancake house', 'daily bread', 'wedding cake', 'best pancake recipe', 'gluten free bread', 'japanese pancake', 'pasta salad', 'alfredo pasta', 'pizza pasta', 'garlic pasta', 'pancake batter', 'lemon cake', 'panera bread', 'sausage pasta', 'bundt cake', 'king cake', 'the pancake house', 'pancake mix recipe', 'wheat bread', 'ice cream cake', 'panera', 'pineapple cake', 'cake flour', 'pasta sauce recipe', 'butter cake', 'recipes', 'bread machine', 'banana pancake recipe', 'bread yeast', 'homemade pasta', 'chocolate cake', 'vanilla cake', 'pasta recipes', 'sourdough bread', 'bread recipe', 'how to make pancake mix', 'bread flour', 'how to make pancake', 'pancake mix', 'cake mix', 'pancake recipe', 'bread pudding', 'make pancake mix', 'chocolate cake recipe', 'original pancake house', 'mug cake', 'pancake day', 'cake near me', 'banana pancake', 'pound cake', 'banana bread recipe', 'cake recipe', 'spinach pasta', 'chocolate', 'penne pasta', 'bread cheese', 'homemade pancake', 'oatmeal cookie recipe', 'cookie dough', 'edible cookie dough', 'chocolate chip cookie', 'cookie butter', 'fortune cookie', 'american cookie', 'cookie recipe', 'cookies', 'cookie jar', 'chocolate chip cookie recipe', 'chocolate chip cookies', 'cookie cutters', 'cookie dough recipe', 'cookie cutter', 'cookie monster', 'sugar cookie recipe', 'girl scout cookie', 'peanut butter cookie', 'cookie cake', 'chocolate cookie recipe', 'sugar cookie', 'cookie recipes', 'cookie clicker', 'butter cookie recipe'])
# Video_Chat_Platforms
# (            Google hangouts  Zoom  QuarantineChat  HouseParty  Zoom Party
# date
# 2019-12-31                0     3               0           0           0
# 2020-01-01                0     2               0           0           0
# 2020-01-02                0     3               0           0           0
# 2020-01-03                0     4               0           0           0
# 2020-01-04                0     3               0           0           0
# ...                     ...   ...             ...         ...         ...
# 2020-05-24                1    20               0           0           0
# 2020-05-25                1    17               0           0           0
# 2020-05-26                2    35               0           0           0
# 2020-05-27                2    37               0           0           0
# 2020-05-28                2    37               0           0           0
#
# [150 rows x 5 columns], ['house party', 'join zoom meeting', 'houseparty app', 'house', 'zoom background', 'zoom call', 'how to use hangouts', 'free zoom', 'google hangout', 'google hangouts meet', 'google meet', 'zoom birthday party', 'zoom watch party', 'zoom backgrounds', 'zoom', 'google hangouts video', 'get houseparty', 'houseparty games', 'hangouts meet', 'games on zoom', 'houseparty login', 'google zoom', 'zoom party themes', 'meet', 'games to play on zoom', 'how to zoom meeting', 'fortnite houseparty', 'houseparty app safe', 'virtual birthday party', 'houseparty on mac', 'how to play games on houseparty', 'zoom online', 'zoom account', 'what is zoom', 'zoom party ideas', 'google hangouts meeting', 'how to use houseparty', 'house party game', 'how to use zoom', 'zoom login', 'netflix watch party', 'what is houseparty app', 'zoom house party', 'hangouts chat', 'how to zoom', 'zoom meeting', 'google hangouts app', 'zoom party games', 'hangouts google login', 'google meeting', 'nike zoom', 'google hangouts free', 'houseparty download', 'hangouts app', 'zoom background change', 'what is houseparty', 'zoom join', 'google hangouts online', 'google chat', 'google hangouts chat', 'zoom party background', 'how to use google hangouts', 'houseparty game', 'how does houseparty work', 'houseparty online', 'house party app games', 'what is a zoom party', 'google classroom hangouts', 'houseparty app games', 'house party app', 'zoom meetings', 'download zoom', 'house party vs zoom', 'zoom vs houseparty', 'houseparty on computer', 'google hangouts video chat', 'dodgers zoom party', 'zoom stock', 'jackbox party pack', 'google video chat', 'how many people on houseparty', 'games on houseparty', 'zoom birthday party ideas', 'google hangouts call', 'what is google hangouts', 'zoom games', 'zoom app', 'hangout', 'zoom video', 'zoom dance party', 'netflix party', 'houseparty chrome', 'virtual zoom background'])
# Live_Virtual_Performance
# (            Billie Eilish  BTS  Dua Lipa  Sophia Ankel
# date
# 2019-12-31              8    9         1             0
# 2020-01-01              9   37         8             0
# 2020-01-02              7    8         1             0
# 2020-01-03              7    7         1             0
# 2020-01-04              8    7         1             0
# ...                   ...  ...       ...           ...
# 2020-05-24              4    7         1             0
# 2020-05-25              4    7         1             0
# 2020-05-26              4    7         1             0
# 2020-05-27              8    7         1             0
# 2020-05-28              8    6         1             0
#
# [150 rows x 4 columns], ['bts wallpaper', 'dua lipa youtube', 'billie eilish eyes', 'is billie eilish', 'physical', 'bts jimin', 'everything i wanted', 'billie eilish songs', 'everything i wanted billie eilish', 'dua lipa one kiss', 'bts tour 2020', 'billie eilish body', 'dua lipa anwar', 'dua lipa song', 'bts 2020', 'dua lipa album', 'what is billie eilish', 'jungkook', 'dua lipa break my heart lyrics', 'dua lipa anwar hadid', 'billie eilish grammy', 'billie eilish net worth', 'grammys', 'bts tickets', 'billie eilish song', 'break my heart lyrics', 'jimin', 'billie eilish lyrics', 'billie eilish grammys 2020', 'bts songs', 'dua lipa height', 'bts album', 'bad guy', 'bts suga', 'billie eilish bikini', 'dua lipa video', 'on bts', 'dua lipa break my heart', 'bts members', 'jin', 'billie eilish concert', 'dua lipa songs', 'jin bts', 'dua lipa lyrics', 'on', 'dua lipa new rules', 'dua lipa rules', 'bts tour', 'kpop', 'billie eilish 2020', 'bts meaning', 'dua lipa dance', 'twitter bts', 'dua lipa real name', 'physical dua lipa', 'bts jungkook', 'anwar hadid', 'what is dua lipa', 'billie eilish grammys', 'bts lyrics', 'future nostalgia', 'billie eilish nude', 'what is bts', 'billie eilish age', 'bts concert', 'billie eilish tour', 'suga', 'bad guy billie eilish', 'billie eilish music', 'future nostalgia dua lipa', 'bts army', 'dua lipa age', 'dua lipa name', 'grammys 2020', 'billie eilish brother'])
# Cameo
# (            Steven Galanis  Rachel Dratch  Mandy Moore  \
# date
# 2019-12-31               0              3           12
# 2020-01-01               0              3           13
# 2020-01-02               0              2           18
# 2020-01-03               0              2           13
# 2020-01-04               0              2           18
# ...                    ...            ...          ...
# 2020-05-24               0              1           16
# 2020-05-25               0              2           21
# 2020-05-26               0              1           12
# 2020-05-27               0              1           13
# 2020-05-28               0              1           11
#
#             Restaurant Workers' Relief Fund
# date
# 2019-12-31                                0
# 2020-01-01                                0
# 2020-01-02                                0
# 2020-01-03                                0
# 2020-01-04                                0
# ...                                     ...
# 2020-05-24                                1
# 2020-05-25                                0
# 2020-05-26                                1
# 2020-05-27                                1
# 2020-05-28                                0
#
# [150 rows x 4 columns], ['snl rachel dratch', 'a walk to remember', 'john krasinski', 'mandy moore show', 'rachel dratch 30 rock', 'mandy moore walk to remember', 'how old is mandy moore', 'mandy moore age', 'ryan adams mandy moore', 'who is mandy moore', 'milo ventimiglia', 'mandy moore 2020', 'mandy moore movies', 'candy mandy moore', 'mandy moore net worth', 'mandy moore husband', 'rachel dratch commercial', 'rachel dratch husband', 'mandy moore this is us', 'chris evans', 'mandy moore songs', 'tangled', 'ryan adams', 'mandy moore princess diaries', 'midway', 'mandy moore a walk to remember', 'mandy moore movie', 'triangle restaurant workers relief fund', 'mandy moore kids', 'princess diaries', 'this is us', 'mandy moore midway', 'debbie downer', 'smart park commercial'])
# Social_Media
# (            Memes  TikTok  Instagram
# date
# 2019-12-31     20       9        100
# 2020-01-01     20       8         99
# 2020-01-02     17      11         82
# 2020-01-03     19      10         79
# 2020-01-04     22      11         77
# ...           ...     ...        ...
# 2020-05-24     14      18         72
# 2020-05-25     14      19         77
# 2020-05-26     14      19         71
# 2020-05-27     15      19         71
# 2020-05-28     15      19         71
#
# [150 rows x 3 columns], ['tik tok', 'instagram captions', 'corona memes', 'tiktok dances', 'memes 2020', 'how to make a tiktok', 'instagram quotes', 'you memes', 'how to tiktok', 'tiktok followers', 'instagram profile', 'tiktok famous', 'renegade', 'kobe bryant instagram', 'instagram account', 'reddit memes', 'happy memes', 'tiktok videos', 'gif memes', 'tiktok money', 'how to delete instagram account', 'how to post on instagram', 'tiktok song', 'delete instagram', 'how to delete instagram', 'instagram followers', 'tiktok app', 'addison tiktok', 'best memes', 'instagram search', 'dank memes', 'covid memes', 'tiktok candy', 'tiktok charli', 'meme', 'delete instagram account', 'tiktok login', 'tiktok songs', 'instagram online', 'love memes', 'work memes', 'tiktok boys', 'login instagram', 'captions for instagram', 'tiger king memes', 'quarantine memes', 'school memes', 'spongebob memes', 'download tiktok', 'what is tiktok', 'instagram live', 'download instagram', 'instagram likes', 'good memes', 'corona virus memes', 'coronavirus memes', 'memes funny', 'snapchat', 'in', 'dog memes', 'what is instagram', 'tiktok likes', 'tiktok stock', 'instagram app', 'tiktok coffee', 'trump memes', 'birthday memes', 'insta', 'cat memes', 'tiktok calculator', 'tiktok dance', 'clean memes', 'instagram fonts', 'instagram stories'])
# TikTok
# (            airplane  Hibachi grill  Hooters  Ciara  Usher
# date
# 2019-12-31        50              6       24      8     14
# 2020-01-01        57              8       27     57     92
# 2020-01-02        51              4       18      8     13
# 2020-01-03        51              5       18      7     10
# 2020-01-04        52              8       23      9     11
# ...              ...            ...      ...    ...    ...
# 2020-05-24        44              5       24     11     14
# 2020-05-25        45              4       23      9     12
# 2020-05-26        43              3       16     10     11
# 2020-05-27        42              3       18      9      9
# 2020-05-28        39              4       15      7      9
#
# [150 rows x 5 columns], ['outdoor hibachi grill', 'airplane lyrics', 'ciara songs', 'make paper airplane', 'ciara russell wilson', 'hooters near me', 'make a paper airplane', 'how to make a paper airplane', 'hibachi buffet and grill', 'confessions usher', 'airplane for sale', 'paper airplane', 'usher confessions', 'jefferson airplane', 'plane', 'hooters restaurant', 'ciara and russell', 'ciara pregnant', 'japanese hibachi grill near me', 'ciara net worth', 'hibachi grill for sale', 'wingstop', 'future and ciara', 'storm ciara', 'usher yeah', 'hooters menu near me', 'airplane crash', 'usher net worth', 'hibachi express', 'hibachi grill & supreme buffet', 'ciara kids', 'hibachi grill supreme buffet', 'buffet near me', 'usher song', 'usher movie', 'how to make airplane', 'benihana', 'ciara bravo', 'ciara husband', 'coronavirus airplane', 'usher burn', 'youtube usher', 'hibachi grill restaurant', 'usher age', 'usher herpes', 'russell wilson', 'ciara twitter', 'hibachi grill near me', 'singer ciara', 'movie airplane', 'hibachi buffet', 'airplane games', 'sushi near me', 'the hooters', 'the fall of the house of usher', 'wings near me', 'hooters wings', 'ciara russell', 'hooters number', 'hibachi grill menu', 'get up ciara', 'usher raymond', 'hibachi grill and supreme buffet', 'blackstone grill', 'fall of the house of usher', 'food near me', 'ciara wilson', 'hooters wings menu', 'jessie usher', 'hibachi grill & buffet', 'ticket airplane', 'ciara age', 'airplane tickets', 'wings', 'hooters hours', 'usher songs', 'restaurants near me', 'hooters locations', 'hooters jobs', 'ciara son', 'usher grammys', 'chris brown', 'how to make paper airplane', 'buffalo wild wings', 'restaurants', 'beyonce', 'ciara and russell wilson', 'the house of usher', 'first airplane', 'climax usher', 'house of usher', 'flights', 'airplane flights', 'airport', 'twin peaks', 'airplane mode', 'hooter', 'ciara instagram', 'rc airplane', 'hooters bar', 'tokyo grill', 'ciara ig', 'usher wife', 'how to make a airplane', 'japanese hibachi grill', 'hibachi grill express', 'hooters girls', 'future ciara', 'usher kids', 'hibachi near me', 'what is hooters', 'level up', 'hooters menu', 'home hibachi grill', 'hooters delivery', 'hooters las vegas', 'future', 'hooters girl', 'usher 2020', 'prince', 'hibachi grill buffet', 'airplane model', 'airplanes', 'burn', 'jennifer lopez alex rodriguez', 'halftime show', 'super bowl halftime', 'jennifer lopez hustlers', 'jennifer lopez halftime show', 'super bowl', 'jlo', 'jennifer lopez and shakira', 'shakira age', 'age jennifer lopez', 'who is jennifer lopez', 'how old jennifer lopez', 'jennifer lopez super bowl', 'jennifer lopez net worth', 'alex rodriguez', 'hustlers', 'jennifer lopez superbowl', 'jennifer lopez movies', 'jennifer lopez daughter', 'jennifer lopez husband', 'jennifer lopez movie', 'shakira', 'jennifer lopez kids', 'how old is jennifer lopez', 'shakira jennifer lopez'])
# Instagram
# (            memes  video chat  makeup tutorials  distance dance  \
# date
# 2019-12-31     52           2                 0               0
# 2020-01-01     54           2                 0               0
# 2020-01-02     44           1                 0               0
# 2020-01-03     51           1                 0               0
# 2020-01-04     57           1                 0               0
# ...           ...         ...               ...             ...
# 2020-05-24     36           2                 0               0
# 2020-05-25     38           2                 0               0
# 2020-05-26     38           2                 0               0
# 2020-05-27     39           2                 0               0
# 2020-05-28     39           2                 0               0
#
#             working_from_home
# date
# 2019-12-31                  0
# 2020-01-01                  0
# 2020-01-02                  0
# 2020-01-03                  0
# 2020-01-04                  0
# ...                       ...
# 2020-05-24                  0
# 2020-05-25                  0
# 2020-05-26                  0
# 2020-05-27                  0
# 2020-05-28                  0
#
# [150 rows x 5 columns], ['live chat', 'best makeup tutorials', 'easy makeup tutorials', 'corona memes', 'random video chat', 'you memes', 'how to video chat', 'zoom chat', 'best video chat', 'make up tutorials', 'google hangouts video chat', 'reddit memes', 'nikkie tutorials', 'happy memes', 'video call', 'facebook chat', 'video chat online', 'gif memes', 'eye makeup tutorials', 'google video chat', 'best memes', 'dank memes', 'google hangouts', 'covid memes', 'makeup tutorials for beginners', 'makeup tutorials for kids', 'dark skin makeup tutorials', 'meme', 'makeup tutorial', 'love memes', 'work memes', 'video chat apps', 'tiger king memes', 'quarantine memes', 'group video chat', 'school memes', 'android video chat', 'google chat', 'google video', 'google hangouts chat', '2020 memes', 'good memes', 'funny memes', 'coronavirus memes', 'corona virus memes', 'video chat facebook', 'messenger video chat', 'dog memes', 'zoom video chat', 'trump memes', 'birthday memes', 'facebook video', 'omegle video chat', 'zoom', 'cat memes', 'cute memes', 'video chat app', 'random chat', 'clean memes'])
# Tiktok_Meme
# (            highschool musical  dance workouts  solo dance  themed dinners  \
# date
# 2019-12-31                  89              18          53               0
# 2020-01-01                  96              19          26               0
# 2020-01-02                 100              17          44               0
# 2020-01-03                  66              16          44               0
# 2020-01-04                  78              18          42               0
# ...                        ...             ...         ...             ...
# 2020-05-24                  17              33          34               0
# 2020-05-25                  16              21          54               0
# 2020-05-26                  42              14          57               0
# 2020-05-27                  28              33          33               0
# 2020-05-28                  42              28          77               0
#
#             distance dance
# date
# 2019-12-31              18
# 2020-01-01              19
# 2020-01-02              17
# 2020-01-03               0
# 2020-01-04              36
# ...                    ...
# 2020-05-24              17
# 2020-05-25              16
# 2020-05-26              29
# 2020-05-27              28
# 2020-05-28              14
#
# [150 rows x 5 columns], ['highschool musical the musical the series', 'dance moms', 'highschool musical songs', 'high school musical', 'highschool musical cast', 'highschool musical the series', 'highschool musical the series cast', 'free dance workouts', 'highschool musical the musical'])
# Virtual_Workouts
# (            Gym  Yoga  Dancing  Toning workout  HIIT workout
# date
# 2019-12-31   62    56       30               0             0
# 2020-01-01   70    61       39               0             1
# 2020-01-02   72    74       29               0             1
# 2020-01-03   66    70       27               0             1
# 2020-01-04   71    69       29               0             1
# ...         ...   ...      ...             ...           ...
# 2020-05-24   45    46       25               0             1
# 2020-05-25   46    44       24               0             2
# 2020-05-26   45    41       21               0             1
# 2020-05-27   42    41       22               0             1
# 2020-05-28   43    44       21               0             1
#
# [150 rows x 5 columns], ['home gym equipment', 'yoga class', 'hiit workout for women', 'beginners yoga', 'dancing meme', 'home hiit workout', 'dancing movies', 'climbing gym', 'best hiit workout', 'cosmic yoga', 'beginner hiit workout', 'hot yoga', 'full body hiit workout', 'adriene yoga', 'fitness gym', 'ballroom dancing', 'rock gym', 'youtube hiit workout', 'bikram yoga', 'baby dancing', 'flirty dancing', 'what is a hiit workout', 'yoga classes', 'the gym', 'yoga studio', 'dancing dolls', 'hiit workout women', 'dancing queen', 'corepower yoga', 'gym hours', '30 minute hiit workout', 'planet fitness', 'hiit ab workout', 'what is yoga', 'slow dancing in the dark', 'yoga pose', 'hiit workout plan', 'line dancing', 'boxing', 'gym shark', 'belly dancing', 'dancing on my own', 'people dancing', 'hiit cardio', 'yoga mat', 'kids yoga', 'dirty dancing', 'gym membership', 'pole dancing classes', 'dancing songs', 'cardio hiit workout', 'basketball gym', 'hiit workouts', 'little gym', 'home gym', 'what is hiit workout', 'hiit training workout', 'hiit at home workout', 'online yoga', 'salsa dancing', 'dancing dog', 'pole dancing', 'yoga with adriene', 'hiit treadmill workout', 'best gym', 'gym equipment', 'tabata workout', 'yoga poses', 'kids dancing', 'dancing in the moonlight', 'gym shoes', 'dancing in the dark', 'total gym', 'free yoga', 'cosmic kids yoga', 'tap dancing', 'open gym', 'gym near me', 'boxing gym', 'dancing gif', 'coronavirus gym', 'yoga pants', 'leg toning workout', 'lenovo yoga', 'yoga near me', 'golds gym', 'yoga workout', 'running hiit workout', 'dancing near me', 'hiit strength workout', 'hiit workout routine', 'dancing with the stars', 'alo yoga', 'gold gym', 'bodyweight hiit workout', 'arm toning workout', 'school gym', 'full body workout', 'my gym', 'power yoga', '20 minute hiit workout', 'youtube yoga'])

# %%
#AZURE COGNITIVE SERVICES

import requests
from azure.cognitiveservices.search.websearch import WebSearchClient
from azure.cognitiveservices.search.websearch.models import SafeSearch
from msrest.authentication import CognitiveServicesCredentials
from jsonpath_ng import jsonpath, parse


subscription_key = "865c1fcf4c99425c9892bddfe34d76ed"
assert subscription_key

# %%
def get_bing_results(keyword_list):

    bing_rel_queries_complete_list = []
    for i in keyword_list:
        headers = {"Ocp-Apim-Subscription-Key": subscription_key}
        params = {"q": i, "textDecorations": True, "textFormat": "HTML"}
        response = requests.get("https://api.cognitive.microsoft.com/bing/v7.0/search", headers=headers, params=params)
        response.raise_for_status()    
        bing_rel_queries_complete_list += rel_query_preprocessing(response.json())
        
    return(bing_rel_queries_complete_list)



def rel_query_preprocessing(bing_search_result_json):
    
    try:
        raw_data = bing_search_result_json['relatedSearches']
        jsonpath_expr = parse('$..text')
        bing_rel_queries = [match.value for match in jsonpath_expr.find(raw_data)]
    
    except KeyError:
        bing_rel_queries = []
        
    bing_rel_queries = list(set(bing_rel_queries))
    
    return(bing_rel_queries)

# %%
# get_bing_results(Topics["Instagram"])

# %% [markdown]
# ### The Output JSON will be created in the following format.
#
#
#     {"Topic Name" :
#          {"interest over time" : #Dataframe
#
#         "related_queries" :
#                     {
#                       "Google": #list
#                       "Bing" :  #list
#                       }
#          }
#     }

# %%
def create_final_json(Topics):
    final_json = {}
    worked_topics = []
    for i in Topics.keys():
        try:
            final_json[i] = {}
            final_json[i]["related_queries"] = {}
            final_json[i]["interest_over_time"],final_json[i]["related_queries"]["Google"] = create_df(Topics[i])
            final_json[i]["related_queries"]["Bing"] = get_bing_results(i)
            worked_topics.append(i)
        except:
            continue
            
    left_out_topics = [x for x in Topics.keys() if x not in worked_topics]
    return(final_json, left_out_topics)

# create_final_json(Topics)

# %%
final_json, left_out_topics = create_final_json(Topics)

# %%
left_out_topics
# Out:
# ['Streaming',
#  'Exercises',
#  'HBO_Shows',
#  'Virtual_Games',
#  'Cooking',
#  'Video_Chat_Platforms',
#  'Live_Virtual_Performance',
#  'Cameo',
#  'Social_Media',
#  'TikTok',
#  'Instagram',
#  'Tiktok_Meme',
#  'Virtual_Workouts']

# %%
final_json
# Out:
# {'Streaming': {'related_queries': {'Google': ['hbo run',
#     'most dangerous game quibi',
#     'hbo max',
#     'amazon prime hbo',
#     'quibi commercial',
#     'the stranger',
#     'the outsider',
#     'hbo on hulu',
#     'best on netflix',
#     'quibi on tv',
#     'hulu shows',
#     'quibi dummy',
#     'free shows online',
#     'showtime',
#     'good netflix movies',
#     'netflix shows',
#     'hbo the outsider',
#     'best hbo movies',
#     'hbo show',
#     't mobile quibi',
#     'outsiders',
#     'free movies and tv shows',
#     'quibi firestick',
#     'shows on netflix',
#     'quibi tv',
#     'good movies on netflix',
#     'amazon hbo',
#     'hulu hbo',
#     'what is quibi',
#     'tv shows',
#     'best netflix shows',
#     'hbo now',
#     'free netflix',
#     'you on netflix',
#     'dummy',
#     'stream free tv shows',
#     'shows on amazon prime',
#     'you netflix',
#     'quibi price',
#     'hbo movies',
#     'hbo free',
#     'survive quibi',
#     'free tv shows',
#     'quibi review',
#     'hbo shows',
#     'hulu',
#     'tv shows to watch',
#     'quibi app',
#     'netflix stock',
#     'quibi shows',
#     'netflix movies 2020',
#     'free movies',
#     'watch shows online free',
#     'most dangerous game',
#     'watch free tv shows online',
#     'quibi roku',
#     'hbo streaming',
#     'outsiders hbo',
#     'netflix account',
#     'netflix series',
#     'hbo series',
#     'hollywood netflix',
#     'hbo free shows',
#     'broadway shows',
#     'broadway shows free',
#     'netflix login',
#     'quibi stock',
#     'best netflix movies',
#     'watch free movies',
#     'reno 911',
#     'movies on hbo',
#     'outer banks netflix',
#     'netflix movies',
#     'free movies and shows',
#     'outer banks',
#     'hbo',
#     'new netflix movies',
#     'movies on netflix',
#     'outsider hbo',
#     'quibi movies',
#     'new on netflix',
#     'free movies online',
#     'quibi streaming',
#     'best movies on netflix',
#     'quibi cost',
#     'free tv shows online',
#     'hbo go',
#     'quibi the stranger',
#     'free hbo',
#     'netflix party',
#     '123movies',
#     'quibi movie',
#     'watch tv shows free',
#     'hbo schedule',
#     'hbo login',
#     'quibi reno 911',
#     'watch tv shows for free']},
#   'interest_over_time':             Quibi  HBO  Netflix  Free Documentries  Free Shows
#   date
#   2019-12-31      0    5       65                  0           0
#   2020-01-01      0    6       81                  0           0
#   2020-01-02      0    5       74                  0           0
#   2020-01-03      0    5       64                  0           0
#   2020-01-04      0    6       72                  0           0
#   ...           ...  ...      ...                ...         ...
#   2020-05-24      1   10       68                  0           0
#   2020-05-25      1   11       67                  0           0
#   2020-05-26      1   10       54                  0           0
#   2020-05-27      1   35       51                  0           0
#   2020-05-28      1   26       51                  0           0
#
#   [150 rows x 5 columns]},
#  'Exercises': {'related_queries': {'Google': ['when is the best time to meditate',
#     'yoga class',
#     'beginners yoga',
#     'running shoe',
#     'ways to meditate',
#     'brooks running shoes',
#     'calories burned walking',
#     'how do you meditate',
#     'people walking',
#     'trail running',
#     'best time to meditate',
#     'cosmic yoga',
#     'walking stick',
#     'learn to meditate',
#     'hot yoga',
#     'dog walking',
#     'walking pneumonia',
#     'adriene yoga',
#     'walking shoes',
#     'running boards',
#     'mens running shoes',
#     'nike running shoes',
#     'bikram yoga',
#     'how to learn to meditate',
#     'rick walking dead',
#     'yoga classes',
#     'yoga studio',
#     'the walking dead season 10',
#     'on running',
#     'corepower yoga',
#     'the walking dead cast',
#     'how to meditate for anxiety',
#     'brooks shoes',
#     'meditation definition',
#     'what is yoga',
#     'nike shoes',
#     'yoga pose',
#     'walking foot',
#     'running lights',
#     'womens running shoes',
#     'meditation',
#     'life is like riding a bicycle',
#     'yoga mat',
#     'kids yoga',
#     'what is meditation',
#     'walking video',
#     'fear the walking dead',
#     'running shorts',
#     'biden running mate',
#     'best shoes for walking',
#     'running store',
#     'brooks running',
#     'online yoga',
#     'yoga with adriene',
#     'how to meditate for beginners',
#     'how to meditate properly',
#     'best running shoes',
#     'walking dead cast',
#     'walking exercise',
#     'brooks',
#     'yoga poses',
#     'walking tall',
#     'how do i meditate',
#     'asics',
#     'walking trails',
#     'meditate on the word',
#     'walking dead',
#     'pneumonia',
#     'free yoga',
#     'nike running',
#     'asics running',
#     'how long should i meditate',
#     'cosmic kids yoga',
#     'who is running for president',
#     'mediate',
#     'how to meditate',
#     'walking trails near me',
#     'yoga pants',
#     'walking company',
#     'lenovo yoga',
#     'meditate lyrics',
#     'how to meditate at home',
#     'yoga near me',
#     'yoga workout',
#     'best walking shoes',
#     'on running shoes',
#     'alo yoga',
#     'season 10 walking dead',
#     'how long to meditate',
#     'learning to meditate',
#     'running shoes',
#     'meditate definition',
#     'running man',
#     'meditate meaning',
#     'why meditate',
#     'how to meditate reddit',
#     'the walking dead',
#     'power yoga',
#     'walking trail',
#     'youtube yoga',
#     'running for president']},
#   'interest_over_time':             Yoga  Walking  Running  Meditate  Bicycle riding
#   date
#   2019-12-31    56       39       70         1               0
#   2020-01-01    59       44       74         1               0
#   2020-01-02    74       43       76         1               0
#   2020-01-03    69       42       69         1               0
#   2020-01-04    68       44       76         1               0
#   ...          ...      ...      ...       ...             ...
#   2020-05-24    46       53       92         1               0
#   2020-05-25    45       56       92         1               0
#   2020-05-26    41       50       87         1               0
#   2020-05-27    41       46       85         1               0
#   2020-05-28    43       42       84         1               0
#
#   [150 rows x 5 columns]},
#  'HBO_Shows': {'related_queries': {'Google': ['imdb true blood',
#     'under the wire',
#     'the sopranos reddit',
#     'ecological succession',
#     'veep seasons',
#     'the high wire',
#     'walmart the wire',
#     'veep season 1',
#     'over the wire',
#     'true blood sookie',
#     'how many seasons of the sopranos',
#     'the wire season 3',
#     'the sopranos ending',
#     'true blood season 4',
#     'true blood books',
#     'amazon the wire',
#     'secondary succession',
#     'the sopranos netflix',
#     'dan egan veep',
#     'primary and secondary succession',
#     'cast of true blood',
#     'the wire',
#     'veep season 3',
#     'sue veep',
#     'daily caller',
#     'godric true blood',
#     'tara true blood',
#     'the wire series',
#     'cast of the sopranos',
#     'cast of veep',
#     'sopranos season 6',
#     'wire cast',
#     'paulie the sopranos',
#     'the sopranos season 1',
#     'michael the wire',
#     'succession of president',
#     'omar the wire',
#     'pioneer species',
#     'veep season 6',
#     'true blood actress',
#     'president succession',
#     'veep episodes',
#     'anna paquin',
#     'catherine veep',
#     'season 2 succession',
#     'daily wire',
#     'primary succession',
#     'the sopranos cast',
#     'lafayette',
#     'veep cast',
#     'bill true blood',
#     'eric true blood',
#     'succession definition',
#     'sam true blood',
#     'pussy the sopranos',
#     'the sopranos movie',
#     'veep season 7',
#     'line of succession',
#     'season 2 true blood',
#     'cast succession',
#     'through the wire',
#     'gary veep',
#     'the sopranos episodes',
#     'jonah veep',
#     'season 4 the wire',
#     'veep characters',
#     'the sopranos season 2',
#     'what is succession',
#     'tom james veep',
#     'succession planning',
#     'barbed wire',
#     'the daily wire',
#     'dan veep',
#     'what is secondary succession',
#     'veep imdb',
#     'omar',
#     'watch true blood',
#     'jason true blood',
#     'show succession',
#     'the wire show',
#     'veep show',
#     'the daily caller',
#     'veep definition',
#     'amy veep',
#     'all the wire',
#     'true blood season 5',
#     'the veep',
#     'veep review',
#     'the sopranos season 6',
#     'in succession',
#     'sopranos season 3',
#     'veep season 5',
#     'true blood cast',
#     'what is primary succession',
#     'primary succession and secondary succession',
#     'order of succession',
#     'annabella sciorra',
#     'ecosystem',
#     'the sopranos season 4',
#     'presidential succession',
#     'hbo succession',
#     'true blood season 6',
#     'lafayette true blood',
#     'season 1 the wire',
#     'true blood seasons',
#     'the sopranos season 5',
#     'walmart wire',
#     'hbo',
#     'the sopranos season 3',
#     'veep season 8',
#     'true blood season 3',
#     'adriana the sopranos',
#     'the succession',
#     'watch the wire',
#     'true blood season 1',
#     'hbo veep',
#     'sopranos cast',
#     'christopher the sopranos',
#     'true blood jessica',
#     'sopranos movie',
#     'the wire cast',
#     'the wire season 2',
#     'succession season 3',
#     'sopranos season 2',
#     'true blood season 7']},
#   'interest_over_time':             Succession  True Blood  The Sopranos  Veep  The Wire
#   date
#   2019-12-31           7           3             2     1        11
#   2020-01-01           7           3             2     1         9
#   2020-01-02           8           3             2     1        10
#   2020-01-03           7           3             2     1        11
#   2020-01-04           8           3             2     1        11
#   ...                ...         ...           ...   ...       ...
#   2020-05-24           7           5             3     2        16
#   2020-05-25           6           6             4     2        16
#   2020-05-26           8           4             3     1        14
#   2020-05-27           6           4             3     1        13
#   2020-05-28           5           5             3     1        13
#
#   [150 rows x 5 columns]},
#  'Virtual_Games': {'related_queries': {'Google': ['webkinz',
#     'words with friends cheat with screenshot',
#     'mario kart tour friends',
#     'animal jam',
#     'words with friends scrabble',
#     'animal crossing qr codes',
#     'words with friends generator',
#     'friends with words cheat',
#     'animal crossing new leaf',
#     'new club penguin',
#     'mario kart world tour',
#     'monopoly app',
#     'penguin game',
#     'monopoly man',
#     'what is a monopoly',
#     'online monopoly',
#     'monopoly board',
#     'club penguin names',
#     'nintendo switch',
#     'club penguin codes',
#     'amiibo new horizons',
#     'thwomp mario kart tour',
#     'play monopoly online',
#     'online games',
#     'club penguin puffle',
#     'monopoly game board',
#     'club penguin rewritten',
#     'games',
#     'animal crossing new horizons amiibo',
#     'reddit animal crossing new horizons',
#     'animal crossing new horizons flowers',
#     'monopoly rules',
#     'words with friends helper',
#     'words with friends dictionary',
#     'words with friends finder',
#     'animal crossing amiibo',
#     'monopoly deal',
#     'what is club penguin',
#     'mario kart tour cheats',
#     'reddit mario kart tour',
#     'monopoly definition',
#     'puffles club penguin',
#     'word generator words with friends',
#     'play club penguin',
#     'in monopoly',
#     'words with friends app',
#     'club penguin is kil',
#     'play words with friends',
#     'monopoly game',
#     'animal crossing new horizons price',
#     'club penguin shut down',
#     'club penguin back',
#     'monopoly money',
#     'mario kart tour twitter',
#     'qr codes animal crossing new horizons',
#     'monopoly games',
#     'club penguin codes 2020',
#     'friends monopoly',
#     'mario kart tour yoshi tour',
#     'animal crossing new horizons fruit',
#     'mario kart tour wiki',
#     'what is monopoly',
#     'animal crossing new horizons designs',
#     'mario kart tour characters',
#     'words with friends help',
#     'word finder',
#     'words with friends cheats',
#     'nintendo',
#     'animal crossing switch',
#     'words with friends board',
#     'monopoly pieces',
#     'words with friends screenshot cheat',
#     'mario kart tour kadomatsu',
#     'animal crossing new horizons house',
#     'is mario kart tour multiplayer',
#     'club penguin online',
#     'words with friends 2 cheat',
#     'club penguin online codes',
#     'kadomatsu',
#     'club penguin login',
#     'clubpenguin',
#     'new horizons villagers',
#     'monopoly safeway',
#     'how to play monopoly',
#     'mario kart tour news',
#     'words with friends screenshot',
#     'club penguin island',
#     'word finder words with friends',
#     'animal crossing new horizons new villagers',
#     'mario kart tour tips',
#     'words for words with friends',
#     'monopoly money start',
#     'animal crossing new horizons guide',
#     'animal crossing new horizons fish',
#     'mario kart tour multiplayer',
#     'monopoly plus',
#     'animal crossing fish',
#     'poptropica',
#     'mario kart tour datamine',
#     'word with friends',
#     'villagers animal crossing new horizons',
#     'club penguin code',
#     'reddit animal crossing',
#     'monopoly mcdonalds',
#     'how much money in monopoly',
#     'words with friends cheat words',
#     'amiibo',
#     'cheat with words with friends',
#     'help with words with friends',
#     'scrabble',
#     'animal crossing new horizons switch',
#     'monopoly cards',
#     'words with friends cheat with board',
#     'animal crossing villagers',
#     'club penguin rewritten codes',
#     'sidesteppers mario kart tour',
#     'what is a standard race in mario kart tour',
#     'how much monopoly money']},
#   'interest_over_time':             Animal Crossing: New Horizons  Club Penguin  Monopoly  \
#   date
#   2019-12-31                              0             2         7
#   2020-01-01                              1             2        12
#   2020-01-02                              1             2         7
#   2020-01-03                              1             2         6
#   2020-01-04                              1             2         7
#   ...                                   ...           ...       ...
#   2020-05-24                             19             2         6
#   2020-05-25                             19             2         7
#   2020-05-26                             16             2         5
#   2020-05-27                             15             2         4
#   2020-05-28                             15             2         4
#
#               Mario Kart Tour  Words With Friends
#   date
#   2019-12-31                1                   7
#   2020-01-01                1                   7
#   2020-01-02                1                   6
#   2020-01-03                1                   7
#   2020-01-04                1                   8
#   ...                     ...                 ...
#   2020-05-24                0                   6
#   2020-05-25                0                   8
#   2020-05-26                0                   6
#   2020-05-27                0                   7
#   2020-05-28                0                   7
#
#   [150 rows x 5 columns]},
#  'Cooking': {'related_queries': {'Google': ['pesto pasta',
#     'coffee cake',
#     'lemon pasta',
#     'shrimp pasta',
#     'bread recipes',
#     'chicken pasta',
#     'garlic bread',
#     'panera bread menu',
#     'homemade bread',
#     'french bread',
#     'pasta sauce',
#     'cake bakery',
#     'pancake near me',
#     'pancakes',
#     'chicken pasta recipes',
#     'cake recipes',
#     'pancake recipes',
#     'birthday cake',
#     'panera menu',
#     'banana bread',
#     'cajun pasta',
#     'pasta recipe',
#     'keto bread',
#     'spaghetti',
#     'white bread',
#     'how to make bread',
#     'pasta near me',
#     'how to make pasta',
#     'easy pancake recipe',
#     'pasta noodles',
#     'pancake breakfast',
#     'chicken recipes',
#     'pancake syrup',
#     'baking bread',
#     'pancake cake',
#     'pasta with chicken',
#     'cakes',
#     'yeast',
#     'cheese cake',
#     'strawberry cake',
#     'ihop',
#     'pancakes recipe',
#     'carrot cake',
#     'pancake house',
#     'daily bread',
#     'wedding cake',
#     'best pancake recipe',
#     'gluten free bread',
#     'japanese pancake',
#     'pasta salad',
#     'alfredo pasta',
#     'pizza pasta',
#     'garlic pasta',
#     'pancake batter',
#     'lemon cake',
#     'panera bread',
#     'sausage pasta',
#     'bundt cake',
#     'king cake',
#     'the pancake house',
#     'pancake mix recipe',
#     'wheat bread',
#     'ice cream cake',
#     'panera',
#     'pineapple cake',
#     'cake flour',
#     'pasta sauce recipe',
#     'butter cake',
#     'recipes',
#     'bread machine',
#     'banana pancake recipe',
#     'bread yeast',
#     'homemade pasta',
#     'chocolate cake',
#     'vanilla cake',
#     'pasta recipes',
#     'sourdough bread',
#     'bread recipe',
#     'how to make pancake mix',
#     'bread flour',
#     'how to make pancake',
#     'pancake mix',
#     'cake mix',
#     'pancake recipe',
#     'bread pudding',
#     'make pancake mix',
#     'chocolate cake recipe',
#     'original pancake house',
#     'mug cake',
#     'pancake day',
#     'cake near me',
#     'banana pancake',
#     'pound cake',
#     'banana bread recipe',
#     'cake recipe',
#     'spinach pasta',
#     'chocolate',
#     'penne pasta',
#     'bread cheese',
#     'homemade pancake',
#     'oatmeal cookie recipe',
#     'cookie dough',
#     'edible cookie dough',
#     'chocolate chip cookie',
#     'cookie butter',
#     'fortune cookie',
#     'american cookie',
#     'cookie recipe',
#     'cookies',
#     'cookie jar',
#     'chocolate chip cookie recipe',
#     'chocolate chip cookies',
#     'cookie cutters',
#     'cookie dough recipe',
#     'cookie cutter',
#     'cookie monster',
#     'sugar cookie recipe',
#     'girl scout cookie',
#     'peanut butter cookie',
#     'cookie cake',
#     'chocolate cookie recipe',
#     'sugar cookie',
#     'cookie recipes',
#     'cookie clicker',
#     'butter cookie recipe']},
#   'interest_over_time':             pancake  pasta  baking hacks  bread  cake
#   date
#   2019-12-31        5     18             0     38    48
#   2020-01-01        9     17             0     41    42
#   2020-01-02        4     17             0     34    35
#   2020-01-03        4     17             0     33    38
#   2020-01-04        7     20             0     38    44
#   ...             ...    ...           ...    ...   ...
#   2020-05-24       10     24             0     53    63
#   2020-05-25        8     24             0     48    59
#   2020-05-26        4     18             0     37    44
#   2020-05-27        5     18             0     37    43
#   2020-05-28        5     19             0     39    46
#
#   [150 rows x 5 columns]},
#  'Video_Chat_Platforms': {'related_queries': {'Google': ['house party',
#     'join zoom meeting',
#     'houseparty app',
#     'house',
#     'zoom background',
#     'zoom call',
#     'how to use hangouts',
#     'free zoom',
#     'google hangout',
#     'google hangouts meet',
#     'google meet',
#     'zoom birthday party',
#     'zoom watch party',
#     'zoom backgrounds',
#     'zoom',
#     'google hangouts video',
#     'get houseparty',
#     'houseparty games',
#     'hangouts meet',
#     'games on zoom',
#     'houseparty login',
#     'google zoom',
#     'zoom party themes',
#     'meet',
#     'games to play on zoom',
#     'how to zoom meeting',
#     'fortnite houseparty',
#     'houseparty app safe',
#     'virtual birthday party',
#     'houseparty on mac',
#     'how to play games on houseparty',
#     'zoom online',
#     'zoom account',
#     'what is zoom',
#     'zoom party ideas',
#     'google hangouts meeting',
#     'how to use houseparty',
#     'house party game',
#     'how to use zoom',
#     'zoom login',
#     'netflix watch party',
#     'what is houseparty app',
#     'zoom house party',
#     'hangouts chat',
#     'how to zoom',
#     'zoom meeting',
#     'google hangouts app',
#     'zoom party games',
#     'hangouts google login',
#     'google meeting',
#     'nike zoom',
#     'google hangouts free',
#     'houseparty download',
#     'hangouts app',
#     'zoom background change',
#     'what is houseparty',
#     'zoom join',
#     'google hangouts online',
#     'google chat',
#     'google hangouts chat',
#     'zoom party background',
#     'how to use google hangouts',
#     'houseparty game',
#     'how does houseparty work',
#     'houseparty online',
#     'house party app games',
#     'what is a zoom party',
#     'google classroom hangouts',
#     'houseparty app games',
#     'house party app',
#     'zoom meetings',
#     'download zoom',
#     'house party vs zoom',
#     'zoom vs houseparty',
#     'houseparty on computer',
#     'google hangouts video chat',
#     'dodgers zoom party',
#     'zoom stock',
#     'jackbox party pack',
#     'google video chat',
#     'how many people on houseparty',
#     'games on houseparty',
#     'zoom birthday party ideas',
#     'google hangouts call',
#     'what is google hangouts',
#     'zoom games',
#     'zoom app',
#     'hangout',
#     'zoom video',
#     'zoom dance party',
#     'netflix party',
#     'houseparty chrome',
#     'virtual zoom background']},
#   'interest_over_time':             Google hangouts  Zoom  QuarantineChat  HouseParty  Zoom Party
#   date
#   2019-12-31                0     3               0           0           0
#   2020-01-01                0     2               0           0           0
#   2020-01-02                0     3               0           0           0
#   2020-01-03                0     4               0           0           0
#   2020-01-04                0     3               0           0           0
#   ...                     ...   ...             ...         ...         ...
#   2020-05-24                1    20               0           0           0
#   2020-05-25                1    17               0           0           0
#   2020-05-26                2    35               0           0           0
#   2020-05-27                2    37               0           0           0
#   2020-05-28                2    37               0           0           0
#
#   [150 rows x 5 columns]},
#  'Live_Virtual_Performance': {'related_queries': {'Google': []},
#   'interest_over_time':             Billie Eilish  BTS  Dua Lipa  Sophia Ankel
#   date
#   2019-12-31              8    9         1             0
#   2020-01-01             10   36         8             0
#   2020-01-02              7    8         1             0
#   2020-01-03              7    7         1             0
#   2020-01-04              7    7         1             0
#   ...                   ...  ...       ...           ...
#   2020-05-24              4    7         1             0
#   2020-05-25              5    7         1             0
#   2020-05-26              4    7         1             0
#   2020-05-27              7    7         1             0
#   2020-05-28              7    6         1             0
#
#   [150 rows x 4 columns]},
#  'Cameo': {'related_queries': {'Google': []},
#   'interest_over_time':             Steven Galanis  Rachel Dratch  Mandy Moore  \
#   date
#   2019-12-31               0              3           12
#   2020-01-01               0              3           13
#   2020-01-02               0              2           18
#   2020-01-03               0              2           13
#   2020-01-04               0              2           18
#   ...                    ...            ...          ...
#   2020-05-24               0              1           16
#   2020-05-25               0              2           21
#   2020-05-26               0              1           12
#   2020-05-27               0              1           13
#   2020-05-28               0              1           11
#
#               Restaurant Workers' Relief Fund
#   date
#   2019-12-31                                0
#   2020-01-01                                0
#   2020-01-02                                0
#   2020-01-03                                0
#   2020-01-04                                0
#   ...                                     ...
#   2020-05-24                                1
#   2020-05-25                                0
#   2020-05-26                                1
#   2020-05-27                                1
#   2020-05-28                                0
#
#   [150 rows x 4 columns]},
#  'Social_Media': {'related_queries': {'Google': []},
#   'interest_over_time':             Memes  TikTok  Instagram
#   date
#   2019-12-31     20       9        100
#   2020-01-01     21       8         99
#   2020-01-02     17      11         83
#   2020-01-03     19      10         79
#   2020-01-04     22      11         77
#   ...           ...     ...        ...
#   2020-05-24     14      19         73
#   2020-05-25     15      19         76
#   2020-05-26     15      19         71
#   2020-05-27     15      19         71
#   2020-05-28     15      18         70
#
#   [150 rows x 3 columns]},
#  'TikTok': {'related_queries': {}},
#  'Instagram': {'related_queries': {}},
#  'Tiktok_Meme': {'related_queries': {}},
#  'Virtual_Workouts': {'related_queries': {'Google': ['home gym equipment',
#     'yoga class',
#     'hiit workout for women',
#     'beginners yoga',
#     'dancing meme',
#     'home hiit workout',
#     'dancing movies',
#     'climbing gym',
#     'best hiit workout',
#     'cosmic yoga',
#     'beginner hiit workout',
#     'hot yoga',
#     'full body hiit workout',
#     'adriene yoga',
#     'fitness gym',
#     'ballroom dancing',
#     'rock gym',
#     'youtube hiit workout',
#     'bikram yoga',
#     'baby dancing',
#     'flirty dancing',
#     'what is a hiit workout',
#     'yoga classes',
#     'the gym',
#     'yoga studio',
#     'dancing dolls',
#     'hiit workout women',
#     'dancing queen',
#     'corepower yoga',
#     'gym hours',
#     '30 minute hiit workout',
#     'planet fitness',
#     'hiit ab workout',
#     'what is yoga',
#     'slow dancing in the dark',
#     'yoga pose',
#     'hiit workout plan',
#     'line dancing',
#     'boxing',
#     'gym shark',
#     'belly dancing',
#     'dancing on my own',
#     'people dancing',
#     'hiit cardio',
#     'yoga mat',
#     'kids yoga',
#     'dirty dancing',
#     'gym membership',
#     'pole dancing classes',
#     'dancing songs',
#     'cardio hiit workout',
#     'basketball gym',
#     'hiit workouts',
#     'little gym',
#     'home gym',
#     'what is hiit workout',
#     'hiit training workout',
#     'hiit at home workout',
#     'online yoga',
#     'salsa dancing',
#     'dancing dog',
#     'pole dancing',
#     'yoga with adriene',
#     'hiit treadmill workout',
#     'best gym',
#     'gym equipment',
#     'tabata workout',
#     'yoga poses',
#     'kids dancing',
#     'dancing in the moonlight',
#     'gym shoes',
#     'dancing in the dark',
#     'total gym',
#     'free yoga',
#     'cosmic kids yoga',
#     'tap dancing',
#     'open gym',
#     'gym near me',
#     'boxing gym',
#     'dancing gif',
#     'coronavirus gym',
#     'yoga pants',
#     'leg toning workout',
#     'lenovo yoga',
#     'yoga near me',
#     'golds gym',
#     'yoga workout',
#     'running hiit workout',
#     'dancing near me',
#     'hiit strength workout',
#     'hiit workout routine',
#     'dancing with the stars',
#     'alo yoga',
#     'gold gym',
#     'bodyweight hiit workout',
#     'arm toning workout',
#     'school gym',
#     'full body workout',
#     'my gym',
#     'power yoga',
#     '20 minute hiit workout',
#     'youtube yoga']},
#   'interest_over_time':             Gym  Yoga  Dancing  Toning workout  HIIT workout
#   date
#   2019-12-31   62    56       30               0             0
#   2020-01-01   70    61       39               0             1
#   2020-01-02   72    74       29               0             1
#   2020-01-03   66    70       27               0             1
#   2020-01-04   71    69       29               0             1
#   ...         ...   ...      ...             ...           ...
#   2020-05-24   45    46       25               0             1
#   2020-05-25   46    44       24               0             2
#   2020-05-26   45    41       21               0             1
#   2020-05-27   42    41       22               0             1
#   2020-05-28   43    44       21               0             1
#
#   [150 rows x 5 columns]}}
